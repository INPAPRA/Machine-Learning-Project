# %% [markdown]
# ANN on Data Set of Developed Countries

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01289698-a530-46a2-b3dd-abede51c2a19" name="files[]" multiple disabled />
#      <output id="result-01289698-a530-46a2-b3dd-abede51c2a19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ANN_Developed_Country_Data_WB.csv to ANN_Developed_Country_Data_WB (1).csv

# %%
import pandas as pd
import numpy as np

# %%
import io
df = pd.read_csv((io.BytesIO(uploaded['ANN_Developed_Country_Data_WB.csv'])))

# %%
df.head()
# Out:
#           Country Country_Code  ... Time_to_start_business  New_business_density
# 0  United Kingdom          GBR  ...                   11.5             10.047050
# 1  United Kingdom          GBR  ...                   11.5             11.153033
# 2  United Kingdom          GBR  ...                   11.5              8.867479
# 3  United Kingdom          GBR  ...                   11.5              8.852136
# 4  United Kingdom          GBR  ...                   11.5              9.686320
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 31 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         236 non-null    object
#  1   Country_Code                                    236 non-null    object
#  2   Category                                        236 non-null    object
#  3   Year                                            236 non-null    int64
#  4   Air_freight_million_ton_km                      197 non-null    float64
#  5   Air_passengers_carried                          197 non-null    float64
#  6   Container_port_traffic_TEU                      231 non-null    float64
#  7   Railways_goods_trans_million_ton-km             109 non-null    float64
#  8   Logistic_performance                            108 non-null    float64
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp = IterativeImputer(max_iter=10, random_state=0)

# %%
df = df.drop(df.columns[[0, 1, 2, 3]], axis=1)

# %%
df.head()
# Out:
#    Air_freight_million_ton_km  ...  New_business_density
# 0                 6215.321000  ...             10.047050
# 1                 6154.451000  ...             11.153033
# 2                 6283.831000  ...              8.867479
# 3                 6615.125000  ...              8.852136
# 4                 6082.739413  ...              9.686320
#
# [5 rows x 27 columns]

# %%
data=imp.fit_transform(df)

# %%
print(data)
# Out:
# [[6.21532100e+03 9.75446310e+07 8.43445800e+06 ... 0.00000000e+00
#   1.15000000e+01 1.00470502e+01]
#  [6.15445100e+03 1.01622807e+08 8.62510200e+06 ... 0.00000000e+00
#   1.15000000e+01 1.11530330e+01]
#  [6.28383100e+03 1.04713553e+08 8.23652289e+06 ... 0.00000000e+00
#   1.15000000e+01 8.86747857e+00]
#  ...
#  [6.69581128e+03 3.53703280e+07 3.26680000e+07 ... 0.00000000e+00
#   2.50000000e+00 8.01314649e+00]
#  [5.06299258e+03 3.80949900e+07 3.36670000e+07 ... 0.00000000e+00
#   2.50000000e+00 8.57863953e+00]
#  [5.19490042e+03 4.04015150e+07 3.66000000e+07 ... 0.00000000e+00
#   1.50000000e+00 1.00107885e+01]]

# %%
 dataset=pd.DataFrame({'Column1': data[:, 0], 'Column2': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3],
                       'Column5': data[:, 4], 'Column6': data[:, 5],'Column7': data[:, 6], 'Column8': data[:, 7],
                       'Column9': data[:, 8], 'Column10': data[:, 9],'Column11': data[:, 10], 'Column12': data[:, 11],
                       'Column13': data[:, 12], 'Column14': data[:, 13],'Column15': data[:, 14], 'Column16': data[:, 15],
                       'Column17': data[:, 16], 'Column18': data[:, 17],'Column19': data[:, 18], 'Column20': data[:, 19],
                      'Column21': data[:, 20],'Column22': data[:, 21],'Column23': data[:, 22],
                       'Column24': data[:, 23],'Column25': data[:, 24],
                      'Column26': data[:, 25],'Column27': data[:, 26]})

# %%
dataset.head()
# Out:
#        Column1      Column2      Column3  ...  Column25  Column26   Column27
# 0  6215.321000   97544631.0  8434458.000  ...       0.0      11.5  10.047050
# 1  6154.451000  101622807.0  8625102.000  ...       0.0      11.5  11.153033
# 2  6283.831000  104713553.0  8236522.886  ...       0.0      11.5   8.867479
# 3  6615.125000  102464509.0  7671299.961  ...       0.0      11.5   8.852136
# 4  6082.739413  101515720.2  7861006.000  ...       0.0      11.5   9.686320
#
# [5 rows x 27 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column1   236 non-null    float64
#  1   Column2   236 non-null    float64
#  2   Column3   236 non-null    float64
#  3   Column4   236 non-null    float64
#  4   Column5   236 non-null    float64
#  5   Column6   236 non-null    float64
#  6   Column7   236 non-null    float64
#  7   Column8   236 non-null    float64
#  8   Column9   236 non-null    float64
#  9   Column10  236 non-null    float64
#  10  Column11  236 non-null    float64
#  11  Column12  236 non-null    float64
#  12  Column13  236 non-null    float64
#  13  Column14  236 non-null    float64
#  14  Column15  236 non-null    float64
#  15  Column16  236 non-null    float64
#  16  Column17  236 non-null    float64
#  17  Column18  236 non-null    float64
#  18  Column19  236 non-null    float64
# ...

# %%
x=dataset[['Column1','Column2','Column3','Column4','Column5','Column6','Column7','Column8','Column9','Column10',
      'Column11','Column12','Column13','Column14','Column15','Column16','Column17','Column18','Column19',
       'Column20', 'Column21', 'Column22','Column23','Column24','Column25','Column26' ]]
y=dataset['Column27']

# %%
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
# %matplotlib inline

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=50)

# %%
import keras

# %%
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Sequential

# %%
x_norm = (x - x.mean()) / x.std()
x_norm.head()
# Out:
#     Column1   Column2   Column3  ...  Column24  Column25  Column26
# 0  0.855420  1.282674 -0.037688  ...  0.367288 -0.826152  0.049426
# 1  0.837412  1.389333 -0.016553  ...  0.367288 -0.826152  0.049426
# 2  0.875689  1.470167 -0.059630  ...  0.367288 -0.826152  0.049426
# 3  0.973704  1.411346 -0.122290  ...  0.367288 -0.826152  0.049426
# 4  0.816196  1.386532 -0.101259  ...  0.367288 -0.826152  0.049426
#
# [5 rows x 26 columns]

# %%
y_norm = (y - y.mean()) / y.std()
y_norm.head()
# Out:
# 0    0.560166
# 1    0.741489
# 2    0.366778
# 3    0.364263
# 4    0.501025
# Name: Column27, dtype: float64

# %%
train_x,test_x,train_y,test_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
n_cols = x_norm.shape[1]

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(100, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build the model
model = regression_model()

# %%
# fit the model
model.fit(train_x, train_y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 6/6 - 0s - loss: 0.6579
# Epoch 2/100
# 6/6 - 0s - loss: 0.3820
# Epoch 3/100
# 6/6 - 0s - loss: 0.2497
# Epoch 4/100
# 6/6 - 0s - loss: 0.1146
# Epoch 5/100
# 6/6 - 0s - loss: 0.0803
# Epoch 6/100
# 6/6 - 0s - loss: 0.0753
# Epoch 7/100
# 6/6 - 0s - loss: 0.0547
# Epoch 8/100
# 6/6 - 0s - loss: 0.0455
# Epoch 9/100
# 6/6 - 0s - loss: 0.0383
# Epoch 10/100
# 6/6 - 0s - loss: 0.0311
# Epoch 11/100
# 6/6 - 0s - loss: 0.0285
# Epoch 12/100
# 6/6 - 0s - loss: 0.0228
# Epoch 13/100
# 6/6 - 0s - loss: 0.0194
# Epoch 14/100
# 6/6 - 0s - loss: 0.0264
# Epoch 15/100
# 6/6 - 0s - loss: 0.0262
# Epoch 16/100
# 6/6 - 0s - loss: 0.0182
# Epoch 17/100
# 6/6 - 0s - loss: 0.0126
# Epoch 18/100
# 6/6 - 0s - loss: 0.0119
# Epoch 19/100
# 6/6 - 0s - loss: 0.0112
# Epoch 20/100
# 6/6 - 0s - loss: 0.0109
# Epoch 21/100
# 6/6 - 0s - loss: 0.0141
# Epoch 22/100
# 6/6 - 0s - loss: 0.0129
# Epoch 23/100
# 6/6 - 0s - loss: 0.0144
# Epoch 24/100
# 6/6 - 0s - loss: 0.0121
# Epoch 25/100
# ...

# %%
loss_val = model.evaluate(test_x, test_y)
y_pred = model.predict(test_x)
loss_val
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1260
# 0.12598773837089539

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_square_error = mean_squared_error(test_y, y_pred)
mean = np.mean(mean_square_error)
standard_deviation = np.std(mean_square_error)
print(mean, standard_deviation)
# Out:
# 0.04487270171959579 0.0

# %%
 from sklearn.metrics import r2_score

# %%
r2_score(test_y, y_pred)
# Out:
# 0.9648112618583918

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, y_pred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.legend()
plt.title("ANN Model")
plt.show()

# %%
history = model.fit(train_x, train_y, validation_split=0.25, epochs=100, batch_size=16, verbose=1)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 2/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 5/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0156
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0068
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0097 - val_loss: 0.0083
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0060
# Epoch 9/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0161
# Epoch 10/100
# ...

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ANN on Data Set of Developing Countries

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-beabfa32-fd34-4fbc-ab82-8de3899df63c" name="files[]" multiple disabled />
#      <output id="result-beabfa32-fd34-4fbc-ab82-8de3899df63c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ANN_Developing_Country_Data_WB.csv to ANN_Developing_Country_Data_WB (1).csv

# %%
import pandas as pd
import numpy as np

# %%
import io
df = pd.read_csv((io.BytesIO(uploaded['ANN_Developing_Country_Data_WB.csv'])))

# %%
df.head()
# Out:
#      Country Country_Code  ... Time_to_start_business  New_business_density
# 0  Argentina          ARG  ...                   29.5              0.240650
# 1  Argentina          ARG  ...                   29.5              0.240467
# 2  Argentina          ARG  ...                   30.0              0.237290
# 3  Argentina          ARG  ...                   25.0              0.189667
# 4  Argentina          ARG  ...                   24.5              0.207609
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 31 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         185 non-null    object
#  1   Country_Code                                    185 non-null    object
#  2   Category                                        185 non-null    object
#  3   Year                                            185 non-null    int64
#  4   Air_freight_million_ton_km                      185 non-null    float64
#  5   Air_passengers_carried                          185 non-null    float64
#  6   Container_port_traffic_TEU                      183 non-null    float64
#  7   Railways_goods_trans_million_ton-km             89 non-null     float64
#  8   Logistic_performance                            87 non-null     float64
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp = IterativeImputer(max_iter=10, random_state=0)

# %%
df = df.drop(df.columns[[0, 1, 2, 3]], axis=1)

# %%
df.head()
# Out:
#    Air_freight_million_ton_km  ...  New_business_density
# 0                  124.583000  ...              0.240650
# 1                  132.675000  ...              0.240467
# 2                  131.685000  ...              0.237290
# 3                  111.663000  ...              0.189667
# 4                  193.301254  ...              0.207609
#
# [5 rows x 27 columns]

# %%
data=imp.fit_transform(df)

# %%
print(data)
# Out:
# [[1.24583000e+02 6.61191500e+06 1.75799000e+06 ... 1.88000000e+01
#   2.95000000e+01 2.40650412e-01]
#  [1.32675000e+02 7.03678400e+06 1.87425900e+06 ... 1.59000000e+01
#   2.95000000e+01 2.40466755e-01]
#  [1.31685000e+02 6.14729000e+06 1.99714600e+06 ... 1.24000000e+01
#   3.00000000e+01 2.37290147e-01]
#  ...
#  [1.04273626e+03 1.70266432e+07 4.56799300e+06 ... 0.00000000e+00
#   4.60000000e+01 6.57481813e+00]
#  [8.92734324e+02 1.88828980e+07 4.66230000e+06 ... 0.00000000e+00
#   4.60000000e+01 8.67781982e+00]
#  [7.67271186e+02 1.97449320e+07 4.45400000e+06 ... 0.00000000e+00
#   4.50000000e+01 1.02077982e+01]]

# %%
dataset=pd.DataFrame({'Column1': data[:, 0], 'Column2': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3],
                       'Column5': data[:, 4], 'Column6': data[:, 5],'Column7': data[:, 6], 'Column8': data[:, 7],
                       'Column9': data[:, 8], 'Column10': data[:, 9],'Column11': data[:, 10], 'Column12': data[:, 11],
                       'Column13': data[:, 12], 'Column14': data[:, 13],'Column15': data[:, 14], 'Column16': data[:, 15],
                       'Column17': data[:, 16], 'Column18': data[:, 17],'Column19': data[:, 18], 'Column20': data[:, 19],
                      'Column21': data[:, 20],'Column22': data[:, 21],'Column23': data[:, 22],
                       'Column24': data[:, 23],'Column25': data[:, 24],
                      'Column26': data[:, 25],'Column27': data[:, 26]})

# %%
dataset.head()
# Out:
#       Column1      Column2      Column3  ...  Column25  Column26  Column27
# 0  124.583000  6611915.000  1757990.000  ...      18.8      29.5  0.240650
# 1  132.675000  7036784.000  1874259.000  ...      15.9      29.5  0.240467
# 2  131.685000  6147290.000  1997146.000  ...      12.4      30.0  0.237290
# 3  111.663000  5694547.000  1626835.356  ...       9.8      25.0  0.189667
# 4  193.301254  9025035.312  1992124.000  ...       9.1      24.5  0.207609
#
# [5 rows x 27 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column1   185 non-null    float64
#  1   Column2   185 non-null    float64
#  2   Column3   185 non-null    float64
#  3   Column4   185 non-null    float64
#  4   Column5   185 non-null    float64
#  5   Column6   185 non-null    float64
#  6   Column7   185 non-null    float64
#  7   Column8   185 non-null    float64
#  8   Column9   185 non-null    float64
#  9   Column10  185 non-null    float64
#  10  Column11  185 non-null    float64
#  11  Column12  185 non-null    float64
#  12  Column13  185 non-null    float64
#  13  Column14  185 non-null    float64
#  14  Column15  185 non-null    float64
#  15  Column16  185 non-null    float64
#  16  Column17  185 non-null    float64
#  17  Column18  185 non-null    float64
#  18  Column19  185 non-null    float64
# ...

# %%
x=dataset[['Column1','Column2','Column3','Column4','Column5','Column6','Column7','Column8','Column9','Column10',
      'Column11','Column12','Column13','Column14','Column15','Column16','Column17','Column18','Column19',
       'Column20', 'Column21', 'Column22','Column23','Column24','Column25','Column26' ]]
y=dataset['Column27']

# %%
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
# %matplotlib inline

# %%
import keras

# %%
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Sequential

# %%
x_norm = (x - x.mean()) / x.std()
x_norm.head()
# Out:
#     Column1   Column2   Column3  ...  Column24  Column25  Column26
# 0 -0.709489 -0.858867 -0.738276  ...  0.910689 -0.063672  0.063988
# 1 -0.705311 -0.846193 -0.716965  ...  0.910689 -0.118903  0.063988
# 2 -0.705822 -0.872727 -0.694441  ...  1.180484 -0.185561  0.092820
# 3 -0.716161 -0.886233 -0.762315  ...  1.180484 -0.235078 -0.195500
# 4 -0.674005 -0.786882 -0.695361  ...  1.180484 -0.248410 -0.224332
#
# [5 rows x 26 columns]

# %%
y_norm = (y - y.mean()) / y.std()
y_norm.head()
# Out:
# 0   -0.791804
# 1   -0.791869
# 2   -0.792988
# 3   -0.809770
# 4   -0.803448
# Name: Column27, dtype: float64

# %%
train_x,test_x,train_y,test_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
n_cols = x_norm.shape[1]

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(100, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build the model
model = regression_model()

# %%
# fit the model
model.fit(train_x, train_y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 0.6247
# Epoch 2/100
# 5/5 - 0s - loss: 0.4045
# Epoch 3/100
# 5/5 - 0s - loss: 0.3561
# Epoch 4/100
# 5/5 - 0s - loss: 0.1777
# Epoch 5/100
# 5/5 - 0s - loss: 0.1357
# Epoch 6/100
# 5/5 - 0s - loss: 0.1103
# Epoch 7/100
# 5/5 - 0s - loss: 0.1276
# Epoch 8/100
# 5/5 - 0s - loss: 0.0620
# Epoch 9/100
# 5/5 - 0s - loss: 0.0774
# Epoch 10/100
# 5/5 - 0s - loss: 0.0516
# Epoch 11/100
# 5/5 - 0s - loss: 0.0471
# Epoch 12/100
# 5/5 - 0s - loss: 0.0406
# Epoch 13/100
# 5/5 - 0s - loss: 0.0332
# Epoch 14/100
# 5/5 - 0s - loss: 0.0273
# Epoch 15/100
# 5/5 - 0s - loss: 0.0234
# Epoch 16/100
# 5/5 - 0s - loss: 0.0231
# Epoch 17/100
# 5/5 - 0s - loss: 0.0229
# Epoch 18/100
# 5/5 - 0s - loss: 0.0268
# Epoch 19/100
# 5/5 - 0s - loss: 0.0225
# Epoch 20/100
# 5/5 - 0s - loss: 0.0232
# Epoch 21/100
# 5/5 - 0s - loss: 0.0241
# Epoch 22/100
# 5/5 - 0s - loss: 0.0174
# Epoch 23/100
# 5/5 - 0s - loss: 0.0156
# Epoch 24/100
# 5/5 - 0s - loss: 0.0153
# Epoch 25/100
# ...

# %%
loss_val = model.evaluate(test_x, test_y)
y_pred = model.predict(test_x)
loss_val
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1342
# 0.13418793678283691

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_square_error = mean_squared_error(test_y, y_pred)
mean = np.mean(mean_square_error)
standard_deviation = np.std(mean_square_error)
print(mean, standard_deviation)
# Out:
# 0.1295150570053566 0.0

# %%
 from sklearn.metrics import r2_score

# %%
r2_score(test_y, y_pred)
# Out:
# 0.9029560162244359

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, y_pred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.legend()
plt.title('ANN Model')
plt.show()

# %%
history = model.fit(train_x, train_y, validation_split=0.25, epochs=100, batch_size=16, verbose=1)
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0054
# Epoch 2/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 9.3023e-04 - val_loss: 0.0060
# Epoch 4/100
# 6/6 [==============================] - 0s 8ms/step - loss: 7.3013e-04 - val_loss: 0.0077
# Epoch 5/100
# 6/6 [==============================] - 0s 8ms/step - loss: 5.0314e-04 - val_loss: 0.0061
# Epoch 6/100
# 6/6 [==============================] - 0s 8ms/step - loss: 4.5744e-04 - val_loss: 0.0070
# Epoch 7/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.7506e-04 - val_loss: 0.0076
# Epoch 8/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.3870e-04 - val_loss: 0.0065
# Epoch 9/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1729e-04 - val_loss: 0.0067
# Epoch 10/100
# ...
