# %% [markdown]
# # Study on World Bank Data

# %% [markdown]
# The Determinants of New Business Density - A Comparative Analysis Between Developed and Developing Countries

# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interativity='all'

# %% [markdown]
# ### Study about Developed Countries

# %% [markdown]
# Uploading the data

# %%
df = pd.read_excel("D:/Phd-IIM Raipur/1st Year Mini Dissertation/Data Set/World Bank/Final Data/Developed_Country_Data_WB.xlsx", None)

# %%
df.keys()
# Out:
# odict_keys(['USA', 'UK', 'NOR', 'CHE', 'DEU', 'CAN', 'AUS', 'SWE', 'FIN', 'JPN', 'AUT', 'BEL', 'DNK', 'ESP', 'FRA', 'HKG', 'IRL', 'ISL', 'NLD', 'SGP', 'TOTAL', 'Sheet1'])

# %%
df = pd.read_excel("D:/Phd-IIM Raipur/1st Year Mini Dissertation/Data Set/World Bank/Final Data/Developed_Country_Data_WB.xlsx", sheet_name='Sheet1')

# %%
df.head()
# Out:
#           Country Country_Code   Category  Year  Air_freight_million_ton_km  \
# 0  United Kingdom          GBR  Developed  2006                 6215.321000
# 1  United Kingdom          GBR  Developed  2007                 6154.451000
# 2  United Kingdom          GBR  Developed  2008                 6283.831000
# 3  United Kingdom          GBR  Developed  2009                 6615.125000
# 4  United Kingdom          GBR  Developed  2010                 6082.739413
#
#    Air_passengers_carried  Container_port_traffic_TEU  \
# 0            9.754463e+07                8.434458e+06
# 1            1.016228e+08                8.625102e+06
# 2            1.047136e+08                8.236523e+06
# 3            1.024645e+08                7.671300e+06
# 4            1.015157e+08                7.861006e+06
#
#    Railways_goods_trans_million_ton-km  Logistic_performance  \
# 0                           106080.000                   NaN
# 1                            34984.864                  4.05
# 2                            12511.867                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                  3.95
#
#    Industry_value_added_current_USD  ...  \
# 0                      5.483257e+11  ...
# 1                      6.102081e+11  ...
# 2                      5.855809e+11  ...
# 3                      4.517339e+11  ...
# 4                      4.669911e+11  ...
#
#    Research_and_development_expenditure_%_of_GDP  \
# 0                                        1.58285
# 1                                        1.62165
# 2                                        1.62307
# 3                                        1.68250
# 4                                        1.66063
#
#    Individuals_using_the_Internet_%_of_population  Poverty_headcount_ratio  \
# 0                                           68.82                      0.2
# 1                                           75.09                      0.3
# 2                                           78.39                      0.3
# 3                                           83.56                      0.2
# 4                                           85.00                      0.1
#
#    Listed_companies  Business_disclosure  Ease_of_doing_business  \
# 0            2913.0                   10                     NaN
# 1            2588.0                   10                     NaN
# 2            2415.0                   10                     NaN
# 3            2179.0                   10                     NaN
# 4            2105.0                   10                     NaN
#
#    Start_up_procedure  Cost_of_business_start_up  Time_to_start_business  \
# 0                 6.0                        0.0                    11.5
# 1                 6.0                        0.0                    11.5
# 2                 6.0                        0.0                    11.5
# 3                 6.0                        0.0                    11.5
# 4                 6.0                        0.0                    11.5
#
#    New_business_density
# 0             10.047050
# 1             11.153033
# 2              8.867479
# 3              8.852136
# 4              9.686320
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 31 columns):
# Country                                           236 non-null object
# Country_Code                                      236 non-null object
# Category                                          236 non-null object
# Year                                              236 non-null int64
# Air_freight_million_ton_km                        197 non-null float64
# Air_passengers_carried                            197 non-null float64
# Container_port_traffic_TEU                        231 non-null float64
# Railways_goods_trans_million_ton-km               109 non-null float64
# Logistic_performance                              108 non-null float64
# Industry_value_added_current_USD                  231 non-null float64
# Manufacturing_value added_%_of_GDP                231 non-null float64
# Services_value_added_%_of_GDP                     231 non-null float64
# Employment_in_industry_%_of_total_employment      236 non-null float64
# GDP_per_capita_current_USD                        236 non-null float64
# Final_consumption                                 236 non-null float64
# Primary_completion_rate                           110 non-null float64
# Educational_attainment                            147 non-null float64
# High_technology_exports_current_USD               216 non-null float64
# Trademark_applications_total                      223 non-null float64
# Patent_applications                               226 non-null float64
# Scientific_technical_journal_articles             223 non-null float64
# Research_and_development_expenditure_%_of_GDP     201 non-null float64
# Individuals_using_the_Internet_%_of_population    233 non-null float64
# Poverty_headcount_ratio                           167 non-null float64
# Listed_companies                                  180 non-null float64
# Business_disclosure                               236 non-null int64
# Ease_of_doing_business                            74 non-null float64
# Start_up_procedure                                229 non-null float64
# Cost_of_business_start_up                         236 non-null float64
# Time_to_start_business                            229 non-null float64
# New_business_density                              236 non-null float64
# dtypes: float64(26), int64(2), object(3)
# memory usage: 57.2+ KB

# %%
plt.hist((df['New_business_density']), color = '#1f77b4')
plt.xlim(0,30)
plt.ylim(0,100)
plt.xlabel('No of Business',fontsize=12)
plt.ylabel('No of Country', fontsize=12)
plt.title("New Business Density in Developed Countries")
plt.show()

# %%
df["New_business_density"].describe()
# Out:
# count    236.000000
# mean       6.630313
# std        6.099509
# min        0.040801
# 25%        3.148613
# 50%        4.600214
# 75%        8.335607
# max       32.437461
# Name: New_business_density, dtype: float64

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp = IterativeImputer(max_iter=10, random_state=0)

# %%
df = df.drop(df.columns[[0, 1, 2, 3]], axis=1)

# %%
df.head()
# Out:
#    Air_freight_million_ton_km  Air_passengers_carried  \
# 0                 6215.321000            9.754463e+07
# 1                 6154.451000            1.016228e+08
# 2                 6283.831000            1.047136e+08
# 3                 6615.125000            1.024645e+08
# 4                 6082.739413            1.015157e+08
#
#    Container_port_traffic_TEU  Railways_goods_trans_million_ton-km  \
# 0                8.434458e+06                           106080.000
# 1                8.625102e+06                            34984.864
# 2                8.236523e+06                            12511.867
# 3                7.671300e+06                                  NaN
# 4                7.861006e+06                                  NaN
#
#    Logistic_performance  Industry_value_added_current_USD  \
# 0                   NaN                      5.483257e+11
# 1                  4.05                      6.102081e+11
# 2                   NaN                      5.855809e+11
# 3                   NaN                      4.517339e+11
# 4                  3.95                      4.669911e+11
#
#    Manufacturing_value added_%_of_GDP  Services_value_added_%_of_GDP  \
# 0                           10.257824                      69.301245
# 1                            9.727962                      69.788253
# 2                            9.620166                      69.790513
# 3                            9.152196                      71.610784
# 4                            9.550935                      70.551904
#
#    Employment_in_industry_%_of_total_employment  GDP_per_capita_current_USD  \
# 0                                     22.062000                44599.697569
# 1                                     22.188999                50566.826596
# 2                                     22.004000                47286.998493
# 3                                     19.611000                38713.137428
# 4                                     19.209999                39435.839902
#
#    ...  Research_and_development_expenditure_%_of_GDP  \
# 0  ...                                        1.58285
# 1  ...                                        1.62165
# 2  ...                                        1.62307
# 3  ...                                        1.68250
# 4  ...                                        1.66063
#
#    Individuals_using_the_Internet_%_of_population  Poverty_headcount_ratio  \
# 0                                           68.82                      0.2
# 1                                           75.09                      0.3
# 2                                           78.39                      0.3
# 3                                           83.56                      0.2
# 4                                           85.00                      0.1
#
#    Listed_companies  Business_disclosure  Ease_of_doing_business  \
# 0            2913.0                   10                     NaN
# 1            2588.0                   10                     NaN
# 2            2415.0                   10                     NaN
# 3            2179.0                   10                     NaN
# 4            2105.0                   10                     NaN
#
#    Start_up_procedure  Cost_of_business_start_up  Time_to_start_business  \
# 0                 6.0                        0.0                    11.5
# 1                 6.0                        0.0                    11.5
# 2                 6.0                        0.0                    11.5
# 3                 6.0                        0.0                    11.5
# 4                 6.0                        0.0                    11.5
#
#    New_business_density
# 0             10.047050
# 1             11.153033
# 2              8.867479
# 3              8.852136
# 4              9.686320
#
# [5 rows x 27 columns]

# %%
data=imp.fit_transform(df)

# %%
print(data)
# Out:
# [[6.21532100e+03 9.75446310e+07 8.43445800e+06 ... 0.00000000e+00
#   1.15000000e+01 1.00470502e+01]
#  [6.15445100e+03 1.01622807e+08 8.62510200e+06 ... 0.00000000e+00
#   1.15000000e+01 1.11530330e+01]
#  [6.28383100e+03 1.04713553e+08 8.23652289e+06 ... 0.00000000e+00
#   1.15000000e+01 8.86747857e+00]
#  ...
#  [6.69581128e+03 3.53703280e+07 3.26680000e+07 ... 0.00000000e+00
#   2.50000000e+00 8.01314649e+00]
#  [5.06299258e+03 3.80949900e+07 3.36670000e+07 ... 0.00000000e+00
#   2.50000000e+00 8.57863953e+00]
#  [5.19490042e+03 4.04015150e+07 3.66000000e+07 ... 0.00000000e+00
#   1.50000000e+00 1.00107885e+01]]

# %%
dataset=pd.DataFrame({'Air_freight': data[:, 0], 'Air_passenger': data[:, 1], 'Container_traffic': data[:, 2], 'Railway_transport': data[:, 3],
                       'Logistic_performance': data[:, 4], 'Industry_valueadded': data[:, 5],'Mfg_valueadded': data[:, 6], 'Service_valueadded': data[:, 7],
                       'Emp_in_industry': data[:, 8], 'GDP_per_capita': data[:, 9],'Final_consumption': data[:, 10], 'Primary_completion': data[:, 11],
                       'Edu_attainment': data[:, 12], 'Hightech_export': data[:, 13],'Treadmark_appl': data[:, 14], 'Patent_appl': data[:, 15],
                       'Scientific_journal': data[:, 16], 'R&D_exp': data[:, 17],'Individual_using_internet': data[:, 18], 'Poverty_headcount': data[:, 19],
                      'Listed_companies': data[:, 20],'Business_disclosure': data[:, 21],'Ease_of_doing_business': data[:, 22],
                       'Start_up_procedure': data[:, 23],'Cost_of_business': data[:, 24],
                      'Time_to_start_business': data[:, 25],'New_business_density': data[:, 26]})

# %%
dataset.head()
# Out:
#    Air_freight  Air_passenger  Container_traffic  Railway_transport  \
# 0  6215.321000   9.754463e+07       8.434458e+06      106080.000000
# 1  6154.451000   1.016228e+08       8.625102e+06       34984.864000
# 2  6283.831000   1.047136e+08       8.236523e+06       12511.867000
# 3  6615.125000   1.024645e+08       7.671300e+06       25703.848664
# 4  6082.739413   1.015157e+08       7.861006e+06       29054.860111
#
#    Logistic_performance  Industry_valueadded  Mfg_valueadded  \
# 0              4.018773         5.483257e+11       10.257824
# 1              4.050000         6.102081e+11        9.727962
# 2              4.059118         5.855809e+11        9.620166
# 3              4.105597         4.517339e+11        9.152196
# 4              3.950000         4.669911e+11        9.550935
#
#    Service_valueadded  Emp_in_industry  GDP_per_capita  ...  R&D_exp  \
# 0           69.301245        22.062000    44599.697569  ...  1.58285
# 1           69.788253        22.188999    50566.826596  ...  1.62165
# 2           69.790513        22.004000    47286.998493  ...  1.62307
# 3           71.610784        19.611000    38713.137428  ...  1.68250
# 4           70.551904        19.209999    39435.839902  ...  1.66063
#
#    Individual_using_internet  Poverty_headcount  Listed_companies  \
# 0                      68.82                0.2            2913.0
# 1                      75.09                0.3            2588.0
# 2                      78.39                0.3            2415.0
# 3                      83.56                0.2            2179.0
# 4                      85.00                0.1            2105.0
#
#    Business_disclosure  Ease_of_doing_business  Start_up_procedure  \
# 0                 10.0               85.864098                 6.0
# 1                 10.0               86.057750                 6.0
# 2                 10.0               85.620366                 6.0
# 3                 10.0               83.388726                 6.0
# 4                 10.0               84.685869                 6.0
#
#    Cost_of_business  Time_to_start_business  New_business_density
# 0               0.0                    11.5             10.047050
# 1               0.0                    11.5             11.153033
# 2               0.0                    11.5              8.867479
# 3               0.0                    11.5              8.852136
# 4               0.0                    11.5              9.686320
#
# [5 rows x 27 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 27 columns):
# Air_freight                  236 non-null float64
# Air_passenger                236 non-null float64
# Container_traffic            236 non-null float64
# Railway_transport            236 non-null float64
# Logistic_performance         236 non-null float64
# Industry_valueadded          236 non-null float64
# Mfg_valueadded               236 non-null float64
# Service_valueadded           236 non-null float64
# Emp_in_industry              236 non-null float64
# GDP_per_capita               236 non-null float64
# Final_consumption            236 non-null float64
# Primary_completion           236 non-null float64
# Edu_attainment               236 non-null float64
# Hightech_export              236 non-null float64
# Treadmark_appl               236 non-null float64
# Patent_appl                  236 non-null float64
# Scientific_journal           236 non-null float64
# R&D_exp                      236 non-null float64
# Individual_using_internet    236 non-null float64
# Poverty_headcount            236 non-null float64
# Listed_companies             236 non-null float64
# Business_disclosure          236 non-null float64
# Ease_of_doing_business       236 non-null float64
# Start_up_procedure           236 non-null float64
# Cost_of_business             236 non-null float64
# Time_to_start_business       236 non-null float64
# New_business_density         236 non-null float64
# dtypes: float64(27)
# memory usage: 49.9 KB

# %%
# bulding the correlation matrix
sns.heatmap(dataset.corr())

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
print(dataset[['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport',
                       'Logistic_performance', 'Industry_valueadded','Mfg_valueadded', 'Service_valueadded',
                       'Emp_in_industry', 'GDP_per_capita','Final_consumption', 'Primary_completion',
                       'Edu_attainment', 'Hightech_export','Treadmark_appl', 'Patent_appl',
                       'Scientific_journal', 'R&D_exp','Individual_using_internet', 'Poverty_headcount',
                      'Listed_companies','Business_disclosure','Ease_of_doing_business',
                       'Start_up_procedure','Cost_of_business',
                      'Time_to_start_business']].corr())
# Out:
#                            Air_freight  Air_passenger  Container_traffic  \
# Air_freight                   1.000000       0.432660           0.774448
# Air_passenger                 0.432660       1.000000           0.254171
# Container_traffic             0.774448       0.254171           1.000000
# Railway_transport             0.300053       0.536086           0.098231
# Logistic_performance          0.599247       0.185002           0.502388
# Industry_valueadded           0.520702       0.698184           0.356303
# Mfg_valueadded               -0.110984       0.242367           0.031791
# Service_valueadded            0.661145       0.057873           0.529185
# Emp_in_industry              -0.109102       0.163553          -0.070105
# GDP_per_capita               -0.427981      -0.221403          -0.453447
# Final_consumption             0.550174       0.729753           0.343760
# Primary_completion            0.046629       0.348257           0.054549
# Edu_attainment               -0.034753       0.235339           0.194610
# Hightech_export               0.600727       0.520049           0.579559
# Treadmark_appl                0.582603       0.639654           0.427291
# Patent_appl                   0.438933       0.443954           0.334258
# Scientific_journal            0.561115       0.789706           0.353264
# R&D_exp                      -0.217934      -0.179962          -0.261042
# Individual_using_internet    -0.189607      -0.049564          -0.301844
# Poverty_headcount            -0.293896       0.219606          -0.113546
# Listed_companies              0.404732       0.548615           0.414967
# Business_disclosure           0.254596       0.308065           0.320643
# Ease_of_doing_business        0.196297       0.246629           0.197441
# Start_up_procedure            0.085805       0.229558           0.113757
# Cost_of_business             -0.203462      -0.248178          -0.213112
# Time_to_start_business       -0.260988      -0.003431          -0.155441
#
#                            Railway_transport  Logistic_performance  \
# Air_freight                         0.300053              0.599247
# Air_passenger                       0.536086              0.185002
# Container_traffic                   0.098231              0.502388
# Railway_transport                   1.000000              0.337856
# Logistic_performance                0.337856              1.000000
# Industry_valueadded                 0.600465              0.410773
# Mfg_valueadded                      0.158578              0.080152
# Service_valueadded                 -0.173170              0.279155
# Emp_in_industry                     0.516198              0.133407
# GDP_per_capita                     -0.179224             -0.076611
# Final_consumption                   0.574674              0.394425
# Primary_completion                 -0.022349             -0.150788
# Edu_attainment                     -0.010701              0.143502
# Hightech_export                     0.584703              0.638170
# Treadmark_appl                      0.504789              0.348501
# Patent_appl                         0.203408              0.301455
# Scientific_journal                  0.694257              0.422791
# R&D_exp                             0.198622              0.195007
# Individual_using_internet          -0.095096              0.021892
# Poverty_headcount                  -0.024708             -0.348860
# Listed_companies                    0.205903              0.006518
# Business_disclosure                -0.098452             -0.066490
# Ease_of_doing_business             -0.100347              0.040150
# Start_up_procedure                  0.368244              0.126970
# Cost_of_business                    0.214347              0.122568
# Time_to_start_business              0.016246             -0.275261
#
#                            Industry_valueadded  Mfg_valueadded  \
# Air_freight                           0.520702       -0.110984
# Air_passenger                         0.698184        0.242367
# Container_traffic                     0.356303        0.031791
# Railway_transport                     0.600465        0.158578
# Logistic_performance                  0.410773        0.080152
# Industry_valueadded                   1.000000        0.279010
# Mfg_valueadded                        0.279010        1.000000
# Service_valueadded                    0.044357       -0.386754
# Emp_in_industry                       0.529985        0.557762
# GDP_per_capita                       -0.270857        0.028826
# Final_consumption                     0.971757        0.189127
# Primary_completion                    0.008733        0.153842
# Edu_attainment                        0.048068        0.332495
# Hightech_export                       0.670140        0.421505
# Treadmark_appl                        0.866227        0.048042
# Patent_appl                           0.852897        0.303896
# Scientific_journal                    0.898475        0.088173
# R&D_exp                               0.249224        0.456025
# Individual_using_internet            -0.078438       -0.148520
# Poverty_headcount                     0.105779        0.015315
# Listed_companies                      0.535294       -0.198110
# Business_disclosure                  -0.016659       -0.202600
# Ease_of_doing_business                0.026466       -0.115997
# Start_up_procedure                    0.537427        0.263846
# Cost_of_business                     -0.056131        0.180613
# Time_to_start_business                0.087511        0.271041
#
#                            Service_valueadded  Emp_in_industry  \
# Air_freight                          0.661145        -0.109102
# Air_passenger                        0.057873         0.163553
# Container_traffic                    0.529185        -0.070105
# Railway_transport                   -0.173170         0.516198
# Logistic_performance                 0.279155         0.133407
# Industry_valueadded                  0.044357         0.529985
# Mfg_valueadded                      -0.386754         0.557762
# Service_valueadded                   1.000000        -0.499544
# Emp_in_industry                     -0.499544         1.000000
# GDP_per_capita                      -0.419074        -0.121862
# Final_consumption                    0.124398         0.454078
# Primary_completion                  -0.024560        -0.192728
# Edu_attainment                      -0.175528        -0.065518
# Hightech_export                      0.090446         0.385801
# Treadmark_appl                       0.260995         0.339852
# Patent_appl                          0.106139         0.397166
# Scientific_journal                   0.160125         0.389010
# R&D_exp                             -0.334553         0.514065
# Individual_using_internet           -0.208502        -0.324036
# Poverty_headcount                   -0.133871         0.124919
# Listed_companies                     0.326517         0.053339
# Business_disclosure                  0.195791        -0.307374
# Ease_of_doing_business               0.046305        -0.269189
# Start_up_procedure                  -0.093401         0.616226
# Cost_of_business                    -0.279727         0.379709
# Time_to_start_business              -0.199343         0.469769
#
#                            GDP_per_capita  ...  Scientific_journal   R&D_exp  \
# Air_freight                     -0.427981  ...            0.561115 -0.217934
# Air_passenger                   -0.221403  ...            0.789706 -0.179962
# Container_traffic               -0.453447  ...            0.353264 -0.261042
# Railway_transport               -0.179224  ...            0.694257  0.198622
# Logistic_performance            -0.076611  ...            0.422791  0.195007
# Industry_valueadded             -0.270857  ...            0.898475  0.249224
# Mfg_valueadded                   0.028826  ...            0.088173  0.456025
# Service_valueadded              -0.419074  ...            0.160125 -0.334553
# Emp_in_industry                 -0.121862  ...            0.389010  0.514065
# GDP_per_capita                   1.000000  ...           -0.402052  0.143293
# Final_consumption               -0.363906  ...            0.941572  0.189225
# Primary_completion               0.075852  ...           -0.039939 -0.227488
# Edu_attainment                   0.348505  ...            0.003601  0.154438
# Hightech_export                 -0.215585  ...            0.666815  0.188105
# Treadmark_appl                  -0.387833  ...            0.852071  0.055202
# Patent_appl                     -0.217668  ...            0.616018  0.326863
# Scientific_journal              -0.402052  ...            1.000000  0.074034
# R&D_exp                          0.143293  ...            0.074034  1.000000
# Individual_using_internet        0.454546  ...           -0.086674  0.308407
# Poverty_headcount               -0.255346  ...            0.148600 -0.099501
# Listed_companies                -0.472449  ...            0.628322 -0.297451
# Business_disclosure             -0.285487  ...            0.075211 -0.434686
# Ease_of_doing_business           0.179312  ...            0.057701 -0.141920
# Start_up_procedure              -0.243538  ...            0.475864  0.130939
# Cost_of_business                 0.123024  ...           -0.104292  0.280581
# Time_to_start_business          -0.186988  ...            0.029509  0.051582
#
#                            Individual_using_internet  Poverty_headcount  \
# Air_freight                                -0.189607          -0.293896
# Air_passenger                              -0.049564           0.219606
# Container_traffic                          -0.301844          -0.113546
# Railway_transport                          -0.095096          -0.024708
# Logistic_performance                        0.021892          -0.348860
# Industry_valueadded                        -0.078438           0.105779
# Mfg_valueadded                             -0.148520           0.015315
# Service_valueadded                         -0.208502          -0.133871
# Emp_in_industry                            -0.324036           0.124919
# GDP_per_capita                              0.454546          -0.255346
# Final_consumption                          -0.075647           0.123274
# Primary_completion                          0.048805           0.247241
# Edu_attainment                              0.180065           0.010131
# Hightech_export                            -0.106420          -0.268598
# Treadmark_appl                             -0.181342           0.145385
# Patent_appl                                -0.033358           0.117840
# Scientific_journal                         -0.086674           0.148600
# R&D_exp                                     0.308407          -0.099501
# Individual_using_internet                   1.000000          -0.163949
# Poverty_headcount                          -0.163949           1.000000
# Listed_companies                           -0.244334           0.531619
# Business_disclosure                        -0.181739           0.098849
# Ease_of_doing_business                      0.190112          -0.012102
# Start_up_procedure                         -0.226134           0.225222
# Cost_of_business                            0.060627          -0.054823
# Time_to_start_business                     -0.396745           0.384789
#
#                            Listed_companies  Business_disclosure  \
# Air_freight                        0.404732             0.254596
# Air_passenger                      0.548615             0.308065
# Container_traffic                  0.414967             0.320643
# Railway_transport                  0.205903            -0.098452
# Logistic_performance               0.006518            -0.066490
# Industry_valueadded                0.535294            -0.016659
# Mfg_valueadded                    -0.198110            -0.202600
# Service_valueadded                 0.326517             0.195791
# Emp_in_industry                    0.053339            -0.307374
# GDP_per_capita                    -0.472449            -0.285487
# Final_consumption                  0.593521             0.053557
# Primary_completion                 0.185016             0.302388
# Edu_attainment                    -0.011137             0.239265
# Hightech_export                    0.091692            -0.001873
# Treadmark_appl                     0.667900             0.057654
# Patent_appl                        0.449310             0.002798
# Scientific_journal                 0.628322             0.075211
# R&D_exp                           -0.297451            -0.434686
# Individual_using_internet         -0.244334            -0.181739
# Poverty_headcount                  0.531619             0.098849
# Listed_companies                   1.000000             0.234793
# Business_disclosure                0.234793             1.000000
# Ease_of_doing_business             0.243643             0.421466
# Start_up_procedure                 0.282084            -0.410344
# Cost_of_business                  -0.348621            -0.583012
# Time_to_start_business             0.199079            -0.304230
#
#                            Ease_of_doing_business  Start_up_procedure  \
# Air_freight                              0.196297            0.085805
# Air_passenger                            0.246629            0.229558
# Container_traffic                        0.197441            0.113757
# Railway_transport                       -0.100347            0.368244
# Logistic_performance                     0.040150            0.126970
# Industry_valueadded                      0.026466            0.537427
# Mfg_valueadded                          -0.115997            0.263846
# Service_valueadded                       0.046305           -0.093401
# Emp_in_industry                         -0.269189            0.616226
# GDP_per_capita                           0.179312           -0.243538
# Final_consumption                        0.014830            0.489960
# Primary_completion                       0.485915           -0.180731
# Edu_attainment                           0.465690           -0.414623
# Hightech_export                          0.031487            0.350148
# Treadmark_appl                          -0.095536            0.371966
# Patent_appl                              0.052689            0.358487
# Scientific_journal                       0.057701            0.475864
# R&D_exp                                 -0.141920            0.130939
# Individual_using_internet                0.190112           -0.226134
# Poverty_headcount                       -0.012102            0.225222
# Listed_companies                         0.243643            0.282084
# Business_disclosure                      0.421466           -0.410344
# Ease_of_doing_business                   1.000000           -0.269976
# Start_up_procedure                      -0.269976            1.000000
# Cost_of_business                        -0.414144            0.437827
# Time_to_start_business                  -0.109143            0.595419
#
#                            Cost_of_business  Time_to_start_business
# Air_freight                       -0.203462               -0.260988
# Air_passenger                     -0.248178               -0.003431
# Container_traffic                 -0.213112               -0.155441
# Railway_transport                  0.214347                0.016246
# Logistic_performance               0.122568               -0.275261
# Industry_valueadded               -0.056131                0.087511
# Mfg_valueadded                     0.180613                0.271041
# Service_valueadded                -0.279727               -0.199343
# Emp_in_industry                    0.379709                0.469769
# GDP_per_capita                     0.123024               -0.186988
# Final_consumption                 -0.131133                0.038172
# Primary_completion                -0.182943               -0.029637
# Edu_attainment                    -0.311839               -0.355086
# Hightech_export                    0.072838               -0.103020
# Treadmark_appl                    -0.208241               -0.032011
# Patent_appl                       -0.149382                0.016102
# Scientific_journal                -0.104292                0.029509
# R&D_exp                            0.280581                0.051582
# Individual_using_internet          0.060627               -0.396745
# Poverty_headcount                 -0.054823                0.384789
# Listed_companies                  -0.348621                0.199079
# Business_disclosure               -0.583012               -0.304230
# Ease_of_doing_business            -0.414144               -0.109143
# Start_up_procedure                 0.437827                0.595419
# Cost_of_business                   1.000000                0.260930
# Time_to_start_business             0.260930                1.000000
#
# [26 rows x 26 columns]

# %%
#Correlation with output variable
cor_target = abs(cor["New_business_density"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Mfg_valueadded          0.643636
# Service_valueadded      0.568598
# Emp_in_industry         0.722904
# R&D_exp                 0.532375
# Start_up_procedure      0.508885
# New_business_density    1.000000
# Name: New_business_density, dtype: float64

# %%
#Correlation with output variable
cor_target = abs(cor["New_business_density"])
#Selecting all correlated features
relevant_features = cor_target[cor_target> -1]
relevant_features
# Out:
# Air_freight                  0.317129
# Air_passenger                0.044698
# Container_traffic            0.189825
# Railway_transport            0.273475
# Logistic_performance         0.063706
# Industry_valueadded          0.343537
# Mfg_valueadded               0.643636
# Service_valueadded           0.568598
# Emp_in_industry              0.722904
# GDP_per_capita               0.007218
# Final_consumption            0.291982
# Primary_completion           0.268103
# Edu_attainment               0.006836
# Hightech_export              0.327367
# Treadmark_appl               0.153998
# Patent_appl                  0.286855
# Scientific_journal           0.202009
# R&D_exp                      0.532375
# Individual_using_internet    0.075682
# Poverty_headcount            0.186995
# Listed_companies             0.133243
# Business_disclosure          0.395702
# Ease_of_doing_business       0.457124
# Start_up_procedure           0.508885
# Cost_of_business             0.389725
# Time_to_start_business       0.370330
# New_business_density         1.000000
# Name: New_business_density, dtype: float64

# %%
x=dataset[['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport',
                       'Logistic_performance', 'Industry_valueadded','Mfg_valueadded', 'Service_valueadded',
                       'Emp_in_industry', 'GDP_per_capita','Final_consumption', 'Primary_completion',
                       'Edu_attainment', 'Hightech_export','Treadmark_appl', 'Patent_appl',
                       'Scientific_journal', 'R&D_exp','Individual_using_internet', 'Poverty_headcount',
                      'Listed_companies','Business_disclosure','Ease_of_doing_business',
                       'Start_up_procedure','Cost_of_business',
                      'Time_to_start_business']]
y=dataset['New_business_density']

# %%
#Backward Elimination
cols = list(x.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport', 'Industry_valueadded', 'Service_valueadded', 'GDP_per_capita', 'Final_consumption', 'Primary_completion', 'Edu_attainment', 'Hightech_export', 'Treadmark_appl', 'Patent_appl', 'Scientific_journal', 'Individual_using_internet', 'Poverty_headcount', 'Listed_companies', 'Ease_of_doing_business', 'Start_up_procedure']
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
#no of features
nof_list=np.arange(1,26)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 25
# Score with 25 features: 0.889534

# %%
cols = list(x.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 25)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(x,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['Air_freight', 'Air_passenger', 'Container_traffic',
#        'Railway_transport', 'Logistic_performance', 'Industry_valueadded',
#        'Mfg_valueadded', 'Service_valueadded', 'Emp_in_industry',
#        'GDP_per_capita', 'Primary_completion', 'Edu_attainment',
#        'Hightech_export', 'Treadmark_appl', 'Patent_appl',
#        'Scientific_journal', 'R&D_exp', 'Individual_using_internet',
#        'Poverty_headcount', 'Listed_companies', 'Business_disclosure',
#        'Ease_of_doing_business', 'Start_up_procedure', 'Cost_of_business',
#        'Time_to_start_business'],
#       dtype='object')

# %%
est = sm.OLS(y, x)
est2 = est.fit()
print(est2.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     New_business_density   R-squared:                       0.917
# Model:                              OLS   Adj. R-squared:                  0.907
# Method:                   Least Squares   F-statistic:                     92.91
# Date:                  Thu, 06 Aug 2020   Prob (F-statistic):           2.64e-99
# Time:                          22:13:08   Log-Likelihood:                -467.29
# No. Observations:                   236   AIC:                             986.6
# Df Residuals:                       210   BIC:                             1077.
# Df Model:                            25
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Air_freight               -3.427e-05      0.000     -0.246      0.806      -0.000       0.000
# Air_passenger              1.824e-07   1.48e-08     12.314      0.000    1.53e-07    2.12e-07
# Container_traffic          3.918e-07    6.7e-08      5.846      0.000     2.6e-07    5.24e-07
# Railway_transport             0.0001   1.77e-05      6.726      0.000    8.41e-05       0.000
# Logistic_performance         -3.3557      0.942     -3.564      0.000      -5.212      -1.500
# Industry_valueadded       -1.304e-11    3.7e-12     -3.522      0.001   -2.03e-11   -5.74e-12
# Mfg_valueadded               -0.1717      0.062     -2.764      0.006      -0.294      -0.049
# Service_valueadded            0.1458      0.042      3.503      0.001       0.064       0.228
# Emp_in_industry              -0.0185      0.105     -0.175      0.861      -0.226       0.189
# GDP_per_capita             5.184e-05   2.18e-05      2.380      0.018    8.89e-06    9.48e-05
# Final_consumption         -2.205e-11   1.94e-12    -11.375      0.000   -2.59e-11   -1.82e-11
# Primary_completion           -0.7199      0.077     -9.348      0.000      -0.872      -0.568
# Edu_attainment               -0.4843      0.066     -7.390      0.000      -0.613      -0.355
# Hightech_export           -9.416e-11   1.08e-11     -8.726      0.000   -1.15e-10   -7.29e-11
# Treadmark_appl                0.0001   1.89e-05      6.715      0.000    8.95e-05       0.000
# Patent_appl                   0.0002   1.76e-05     10.352      0.000       0.000       0.000
# Scientific_journal            0.0004   4.28e-05      9.057      0.000       0.000       0.000
# R&D_exp                       0.4857      0.471      1.032      0.303      -0.442       1.413
# Individual_using_internet     0.0066      0.026      0.250      0.803      -0.046       0.059
# Poverty_headcount            -3.9902      0.994     -4.013      0.000      -5.950      -2.030
# Listed_companies             -0.0031      0.000     -6.203      0.000      -0.004      -0.002
# Business_disclosure          -0.0013      0.116     -0.012      0.991      -0.230       0.227
# Ease_of_doing_business        1.1861      0.090     13.248      0.000       1.010       1.363
# Start_up_procedure           -0.1528      0.156     -0.978      0.329      -0.461       0.155
# Cost_of_business             -0.0216      0.013     -1.604      0.110      -0.048       0.005
# Time_to_start_business       -0.0401      0.025     -1.572      0.117      -0.090       0.010
# ==============================================================================
# Omnibus:                        4.515   Durbin-Watson:                   1.081
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                5.223
# Skew:                           0.145   Prob(JB):                       0.0734
# Kurtosis:                       3.669   Cond. No.                     1.37e+13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Code for VIF Calculation

#Writing a function to calculate the VIF values

def vif_cal(input_data, dependent_col):
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y, x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
#Calculating VIF values using that function
vif_cal(input_data=dataset, dependent_col="New_business_density")
# Out:
# Air_freight  VIF =  15.13
# Air_passenger  VIF =  21.83
# Container_traffic  VIF =  24.87
# Railway_transport  VIF =  10.26
# Logistic_performance  VIF =  2.97
# Industry_valueadded  VIF =  124.24
# Mfg_valueadded  VIF =  9.07
# Service_valueadded  VIF =  6.73
# Emp_in_industry  VIF =  11.17
# GDP_per_capita  VIF =  6.97
# Final_consumption  VIF =  343.31
# Primary_completion  VIF =  8.35
# Edu_attainment  VIF =  12.66
# Hightech_export  VIF =  22.48
# Treadmark_appl  VIF =  30.87
# Patent_appl  VIF =  91.03
# Scientific_journal  VIF =  146.46
# R&D_exp  VIF =  8.66
# Individual_using_internet  VIF =  4.82
# Poverty_headcount  VIF =  4.0
# Listed_companies  VIF =  19.54
# Business_disclosure  VIF =  5.62
# Ease_of_doing_business  VIF =  4.66
# Start_up_procedure  VIF =  7.44
# Cost_of_business  VIF =  3.04
# Time_to_start_business  VIF =  4.33

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn.neighbors import KNeighborsRegressor
lm=LinearRegression()
lm_lasso=Lasso()
lm_ridge=Ridge()
lm_elastic=ElasticNet()

# %%
lm.fit(train_x,train_y)
ypred = lm.predict(test_x)
print ('Coefficients: ', lm.coef_)
print('Variance score: %.2f' % lm.score(x, y))
print('Variance score: %.2f' % lm.score(train_x, train_y))
print('Variance score: %.2f' % lm.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [-8.60794351e-04  1.13854882e-07  6.15191279e-07  1.27400348e-04
#  -1.78100065e+00 -2.63506620e-11  3.44865889e-02  2.63517673e-01
#   9.53569536e-02  1.13264882e-04 -1.71872112e-11 -1.56273516e-01
#  -7.78540049e-01 -1.00895494e-10  2.44622089e-04  1.61648090e-04
#   4.24091197e-04 -4.99558235e-01  5.24040744e-02 -3.25285898e+00
#  -5.28957480e-03 -1.46646921e-02  1.74450727e+00 -7.23670021e-01
#  -1.88037950e-03  1.98921431e-02]
# Variance score: 0.94
# Variance score: 0.94
# Variance score: 0.93
# R2 Score: 0.93

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Linear Regression")
plt.show()

# %%
lm_lasso.fit(train_x,train_y)
ypred = lm_lasso.predict(test_x)
print ('Coefficients: ', lm_lasso.coef_)
print('Variance score: %.2f' % lm_lasso.score(x, y))
print('Variance score: %.2f' % lm_lasso.score(train_x, train_y))
print('Variance score: %.2f' % lm_lasso.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [ 4.76371363e-04  7.37425126e-08  2.59123354e-07  3.83130706e-05
#  -0.00000000e+00 -1.20310811e-11 -1.51505269e-01  9.69477749e-02
#  -0.00000000e+00  4.36836425e-05 -1.00396104e-11 -0.00000000e+00
#  -2.58899120e-01 -8.54384391e-11  1.41891687e-04  6.57414852e-05
#   2.20900607e-04 -0.00000000e+00  2.00083779e-02 -0.00000000e+00
#  -3.62867982e-03  0.00000000e+00  8.60656228e-01 -0.00000000e+00
#  -3.92047914e-02 -0.00000000e+00]
# Variance score: 0.89
# Variance score: 0.88
# Variance score: 0.91
# R2 Score: 0.91
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 559.176559323883, tolerance: 0.5561912701903781
#   positive)

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("LASSO Regression")
plt.show()

# %%
lm_ridge.fit(train_x,train_y)
ypred = lm_ridge.predict(test_x)
print ('Coefficients: ', lm_ridge.coef_)
print('Variance score: %.2f' % lm_ridge.score(x, y))
print('Variance score: %.2f' % lm_ridge.score(train_x, train_y))
print('Variance score: %.2f' % lm_ridge.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [-8.27318908e-04  1.14271263e-07  6.16389652e-07  1.27325042e-04
#  -1.35017972e+00 -2.62193085e-11  3.37246871e-02  2.66321984e-01
#   1.16157950e-01  1.13652883e-04 -1.69396729e-11 -1.59729296e-01
#  -7.79482821e-01 -1.02217229e-10  2.43539540e-04  1.59543256e-04
#   4.17545533e-04 -5.55314366e-01  5.51077140e-02 -2.34899493e+00
#  -5.43686025e-03 -3.49396748e-02  1.74994209e+00 -7.29193756e-01
#  -5.46931211e-03  1.77315828e-02]
# Variance score: 0.94
# Variance score: 0.94
# Variance score: 0.93
# R2 Score: 0.93
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.01445e-26): result may not be accurate.
#   overwrite_a=True).T

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Ridge Regression")
plt.show()

# %%
alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]

# %%
for a in alphas:
    model = ElasticNet(alpha=a).fit(x,y)   
    score = model.score(x, y)
    pred_y = model.predict(x)
    mse = mean_squared_error(y, pred_y)   
    print("Alpha:{0:.4f}, R2:{1:.2f}, MSE:{2:.2f}, RMSE:{3:.2f}"
       .format(a, score, mse, np.sqrt(mse)))
# Out:
# Alpha:0.0001, R2:0.94, MSE:2.22, RMSE:1.49
# Alpha:0.0010, R2:0.94, MSE:2.22, RMSE:1.49
# Alpha:0.0100, R2:0.94, MSE:2.24, RMSE:1.50
# Alpha:0.1000, R2:0.93, MSE:2.48, RMSE:1.57
# Alpha:0.3000, R2:0.93, MSE:2.71, RMSE:1.65
# Alpha:0.5000, R2:0.92, MSE:2.99, RMSE:1.73
# Alpha:0.7000, R2:0.91, MSE:3.27, RMSE:1.81
# Alpha:1.0000, R2:0.90, MSE:3.67, RMSE:1.91
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262.1385412442221, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 263.7957197156344, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 278.03755581902266, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 351.3034367934272, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 450.9549701656864, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 529.200790475246, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 593.5957932634457, tolerance: 0.8742941276457412
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 673.4596331518646, tolerance: 0.8742941276457412
#   positive)

# %%
elastic=ElasticNet(alpha=0.01).fit(train_x, train_y)
ypred = elastic.predict(test_x)
score = elastic.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.929, MSE:3.18, RMSE:1.78
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182.1823680575886, tolerance: 0.5561912701903781
#   positive)

# %%
x_ax = range(len(test_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Elastic Net Regression")
plt.show()

# %%
elastic_cv=ElasticNetCV(alphas=alphas, cv=5)
model = elastic_cv.fit(train_x, train_y)
print(model.alpha_)
print(model.intercept_)
# Out:
# 0.01
# -117.86176630790675
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 368.3919242620953, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326.58778106415923, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 292.61007802646856, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 249.4688639430899, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192.5962945277998, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152.2058850589247, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144.9685433942479, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144.12478839939445, tolerance: 0.43725443929248525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335.74779811278626, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295.81837474846026, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 264.64971247468117, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226.0198081754851, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173.05230839876046, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122.23873681244328, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.52042813495483, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.1137303479912, tolerance: 0.4820824797016312
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 374.69748424665227, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330.2488180716026, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295.05098031299445, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251.1554160302444, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 194.58980771790783, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153.36228210642622, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144.79603200450728, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143.77459897874348, tolerance: 0.44548375305683224
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.3700430584191, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.66055125421144, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 309.3406562708558, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 261.4109662916466, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199.59236077936842, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153.75394911387528, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144.23655962255276, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143.103200160787, tolerance: 0.408329640386525
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 365.261874953181, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.5400748825352, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 269.5368115842922, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215.02625229600432, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143.98036571837275, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.46630456269202, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.286704475979, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.08092337435428, tolerance: 0.4488551871614919
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182.1823680575886, tolerance: 0.5561912701903781
#   positive)

# %%
ypred = model.predict(test_x)
score = model.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.929, MSE:3.18, RMSE:1.78

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Elastic Net Regression")
plt.show()

# %%
lm_elastic.fit(train_x,train_y)
print ('Coefficients: ', lm_elastic.coef_)
print('Variance score: %.2f' % lm_elastic.score(x, y))
# Out:
# Coefficients:  [ 3.14674448e-04  8.12082067e-08  2.77736035e-07  5.16986399e-05
#  -0.00000000e+00 -1.33119213e-11 -1.73278812e-01  1.26501092e-01
#   0.00000000e+00  4.87672920e-05 -1.07575786e-11 -0.00000000e+00
#  -3.13749026e-01 -7.96291297e-11  1.48899278e-04  7.70593184e-05
#   2.26923549e-04  0.00000000e+00  2.71932333e-02 -0.00000000e+00
#  -3.70660812e-03  0.00000000e+00  9.14069918e-01 -0.00000000e+00
#  -4.44591335e-02 -0.00000000e+00]
# Variance score: 0.90
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 471.4433725077881, tolerance: 0.5561912701903781
#   positive)

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(train_x, train_y)
ypred=neigh.predict(test_x)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % neigh.score(x, y))
print('Variance score: %.2f' % neigh.score(train_x, train_y))
print('Variance score: %.2f' % neigh.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Variance score: 0.93
# Variance score: 0.92
# Variance score: 0.95
# R2 Score: 0.95

# %%
model = neigh.fit(train_x, train_y)
ypred = model.predict(test_x)
score = model.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("K Nearest Neighbor Regression")
plt.show()
# Out:
# R2:0.947, MSE:2.39, RMSE:1.55

# %%
x_norm = (x - x.mean()) / x.std()

# %%
y_norm = (y - y.mean()) / y.std()

# %%
train_norm_x,test_norm_x,train_norm_y,test_norm_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
model_lar = linear_model.Lars(n_nonzero_coefs=15)

# %%
model_lar.fit(train_norm_x, train_norm_y)
ypred=model_lar.predict(test_norm_x)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % model_lar.score(x_norm, y_norm))
print('Variance score: %.2f' % model_lar.score(train_norm_x, train_norm_y))
print('Variance score: %.2f' % model_lar.score(test_norm_x, test_norm_y))
print('R2 Score: %.2f' % r2_score(test_norm_y, ypred))
# Out:
# Variance score: 0.83
# Variance score: 0.82
# Variance score: 0.84
# R2 Score: 0.84

# %%
model = model_lar.fit(train_norm_x, train_norm_y)
ypred = model.predict(test_norm_x)
score = model.score(test_norm_x, test_norm_y)
mse = mean_squared_error(test_norm_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_norm_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_norm_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Least Angle Regression")
plt.show()
# Out:
# R2:0.840, MSE:0.20, RMSE:0.45

# %%
model_ARD = linear_model.ARDRegression()

# %%
model_ARD.fit(train_norm_x, train_norm_y)
ypred=model_ARD.predict(test_norm_x)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % model_ARD.score(x_norm, y_norm))
print('Variance score: %.2f' % model_ARD.score(train_norm_x, train_norm_y))
print('Variance score: %.2f' % model_ARD.score(test_norm_x, test_norm_y))
print('R2 Score: %.2f' % r2_score(test_norm_y, ypred))
# Out:
# Variance score: 0.93
# Variance score: 0.93
# Variance score: 0.93
# R2 Score: 0.93

# %%
model = model_ARD.fit(train_norm_x, train_norm_y)
ypred = model.predict(test_norm_x)
score = model.score(test_norm_x, test_norm_y)
mse = mean_squared_error(test_norm_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_norm_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_norm_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("ARD Regression")
plt.show()
# Out:
# R2:0.926, MSE:0.09, RMSE:0.31

# %%
print("R Square value for Simple Regression Training data is ",np.round(lm.score(train_x, train_y)*100,2))
print("R Square value for Lasso Regression Training data is ",np.round(lm_lasso.score(train_x, train_y)*100,2))
print("R Square value for Ridge Regression Training data is ",np.round(lm_ridge.score(train_x, train_y)*100,2))
print("R Square value for Elastic Net Regression Training data is ",np.round(lm_elastic.score(train_x, train_y)*100,2))
print("R Square value for K Nearest Neighbor Regression Training data is ",np.round(neigh.score(train_x, train_y)*100,2))
print("R Square value for Least Angle Regression Training data is ",np.round(model_lar.score(train_norm_x, train_norm_y)*100,2))
print("R Square value for ARD Regression Training data is ",np.round(model_ARD.score(train_norm_x, train_norm_y)*100,2))
# Out:
# R Square value for Simple Regression Training data is  93.92
# R Square value for Lasso Regression Training data is  88.39
# R Square value for Ridge Regression Training data is  93.88
# R Square value for Elastic Net Regression Training data is  89.26
# R Square value for K Nearest Neighbor Regression Training data is  91.85
# R Square value for Least Angle Regression Training data is  81.57
# R Square value for ARD Regression Training data is  93.43

# %%
print("R Square value for Simple Regression Test data is ",np.round(lm.score(test_x, test_y)*100,2))
print("R Square value for Lasso Regression Test data is ",np.round(lm_lasso.score(test_x, test_y)*100,2))
print("R Square value for Ridge Regression Test data is ",np.round(lm_ridge.score(test_x, test_y)*100,2))
print("R Square value for Elastic Net Regression Test data is ",np.round(lm_elastic.score(test_x, test_y)*100,2))
print("R Square value for K Nearest Neighbor Regression Test data is ",np.round(neigh.score(test_x, test_y)*100,2))
print("R Square value for Least Angle Regression Test data is ",np.round(model_lar.score(test_norm_x, test_norm_y)*100,2))
print("R Square value for ARD Regression Test data is ",np.round(model_ARD.score(test_norm_x, test_norm_y)*100,2))
# Out:
# R Square value for Simple Regression Test data is  92.92
# R Square value for Lasso Regression Test data is  90.54
# R Square value for Ridge Regression Test data is  93.04
# R Square value for Elastic Net Regression Test data is  91.23
# R Square value for K Nearest Neighbor Regression Test data is  94.66
# R Square value for Least Angle Regression Test data is  84.04
# R Square value for ARD Regression Test data is  92.61

# %%
plt.figure(figsize=(15,10))
ft_importance_lm=pd.Series(lm.coef_,index=x.columns)
ft_importance_lm.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_lasso=pd.Series(lm_lasso.coef_,index=x.columns)
ft_importance_lm_lasso.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_ridge=pd.Series(lm_ridge.coef_,index=x.columns)
ft_importance_lm_ridge.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_elastic=pd.Series(lm_elastic.coef_,index=x.columns)
ft_importance_lm_elastic.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_LAR=pd.Series(model_lar.coef_,index=x.columns)
ft_importance_lm_LAR.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_ARD=pd.Series(model_ARD.coef_,index=x.columns)
ft_importance_lm_ARD.plot(kind='barh')
plt.show()

# %%
x_norm = (x - x.mean()) / x.std()

# %%
y_norm = (y - y.mean()) / y.std()

# %%
train_x,test_x,train_y,test_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
 from sklearn.model_selection import cross_val_score

# %%
regressor = DecisionTreeRegressor(random_state=0)

# %%
regressor.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
ypred = regressor.predict(test_x)
score_train = regressor.score(train_x, train_y)
score_test = regressor.score(test_x, test_y)
print("R Square value for Decision Tree Regression Training data is ",(score_train))
print("R Square value for Decision Tree Regression Test data is ",(score_test))
print("R Square value for Decision Tree Regression Test data is ",(r2_score(test_y, ypred)))
# Out:
# R Square value for Decision Tree Regression Training data is  0.9999999962385442
# R Square value for Decision Tree Regression Test data is  0.8428111645508249
# R Square value for Decision Tree Regression Test data is  0.8428111645508249

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Decision Tree Regression")
plt.show()

# %%
predictions = regressor.predict(test_x)

# %%
errors = abs(predictions - test_y)

# %%
print('Mean Absolute Error:', round(np.mean(errors), 2), )
# Out:
# Mean Absolute Error: 0.22

# %%
cross_val_score(regressor, x, y, cv=10)
# Out:
# array([  0.30246492,   0.13298906,  -0.1080877 ,  -1.46295919,
#        -25.58217601,   0.46409823,  -3.31394605,  -0.66741167,
#         -0.66344006,  -0.49108292])

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 77.01 %.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiate model with 100 decision trees
rf = RandomForestRegressor( n_estimators = 100, random_state = 0)
# Train the model on training data
rf.fit(train_x, train_y);

# %%
ypred = rf.predict(test_x)
score_train = rf.score(train_x, train_y)
score_test = rf.score(test_x, test_y)
print("R Square value for Random Forest Regression Training data is ",(score_train))
print("R Square value for Random Forest Regression Test data is ",(score_test))
print("R Square value for Random Forest Regression Test data is ",(r2_score(test_y, ypred)))
# Out:
# R Square value for Random Forest Regression Training data is  0.9860757409712375
# R Square value for Random Forest Regression Test data is  0.9349694753861005
# R Square value for Random Forest Regression Test data is  0.9349694753861005

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Random Forest Regression")
plt.show()

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_x)
# Calculate the absolute errors
errors = abs(predictions - test_y)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2),)
# Out:
# Mean Absolute Error: 0.18

# %%
cross_val_score(rf, x, y, cv=10)
# Out:
# array([ -0.39174365,   0.82642206,   0.32432203,  -0.7506495 ,
#        -32.58397903,   0.41306115,   0.45693252,  -0.07769602,
#         -0.33177906,  -0.70655691])

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 94.54 %.

# %%
sns.pairplot(df[['New_business_density', 'Cost_of_business_start_up', 'Ease_of_doing_business' , 'Listed_companies', 'Individuals_using_the_Internet_%_of_population', 
              'Educational_attainment','Services_value_added_%_of_GDP', 'Manufacturing_value added_%_of_GDP']])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(df[['New_business_density', 'Ease_of_doing_business']])

# %% [markdown]
# ### Study about Developing Countries

# %%
df = pd.read_excel("D:/Phd-IIM Raipur/1st Year Mini Dissertation/Data Set/World Bank/Final Data/Developing_Country_Data_WB.xlsx", None)

# %%
df.keys()
# Out:
# odict_keys(['ARG', 'BGD', 'BGR', 'BRA', 'CHN', 'IDN', 'IND', 'IRN', 'KWT', 'MEX', 'MYS', 'PHL', 'POL', 'QAT', 'ROU', 'RUS', 'THA', 'TUR', 'VEN', 'ZAF', 'TOTAL', 'Sheet1'])

# %%
df = pd.read_excel("D:/Phd-IIM Raipur/1st Year Mini Dissertation/Data Set/World Bank/Final Data/Developing_Country_Data_WB.xlsx", sheet_name='Sheet1')

# %%
df.head()
# Out:
#      Country Country_Code    Category  Year  Air_freight_million_ton_km  \
# 0  Argentina          ARG  Developing  2006                  124.583000
# 1  Argentina          ARG  Developing  2007                  132.675000
# 2  Argentina          ARG  Developing  2008                  131.685000
# 3  Argentina          ARG  Developing  2009                  111.663000
# 4  Argentina          ARG  Developing  2010                  193.301254
#
#    Air_passengers_carried  Container_port_traffic_TEU  \
# 0            6.611915e+06                1.757990e+06
# 1            7.036784e+06                1.874259e+06
# 2            6.147290e+06                1.997146e+06
# 3            5.694547e+06                1.626835e+06
# 4            9.025035e+06                1.992124e+06
#
#    Railways_goods_trans_million_ton-km  Logistic_performance  \
# 0                                  NaN                   NaN
# 1                                  NaN                  2.81
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                  2.75
#
#    Industry_value_added_current_USD  ...  \
# 0                      6.791435e+10  ...
# 1                      7.882717e+10  ...
# 2                      9.499019e+10  ...
# 3                      8.419046e+10  ...
# 4                      1.070031e+11  ...
#
#    Research_and_development_expenditure_%_of_GDP  \
# 0                                        0.45216
# 1                                        0.46007
# 2                                        0.47055
# 3                                        0.58398
# 4                                        0.56104
#
#    Individuals_using_the_Internet_%_of_population  Poverty_headcount_ratio  \
# 0                                       20.927202                      3.2
# 1                                       25.946633                      2.6
# 2                                       28.112623                      2.6
# 3                                       34.000000                      2.5
# 4                                       45.000000                      2.2
#
#    Listed_companies  Business_disclosure  Ease_of_doing_business  \
# 0             101.0                    7                     NaN
# 1             106.0                    7                     NaN
# 2             107.0                    7                     NaN
# 3             101.0                    7                     NaN
# 4             101.0                    7                     NaN
#
#    Start_up_procedure  Cost_of_business_start_up  Time_to_start_business  \
# 0                13.0                       18.8                    29.5
# 1                13.0                       15.9                    29.5
# 2                14.0                       12.4                    30.0
# 3                14.0                        9.8                    25.0
# 4                14.0                        9.1                    24.5
#
#    New_business_density
# 0              0.240650
# 1              0.240467
# 2              0.237290
# 3              0.189667
# 4              0.207609
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 31 columns):
# Country                                           185 non-null object
# Country_Code                                      185 non-null object
# Category                                          185 non-null object
# Year                                              185 non-null int64
# Air_freight_million_ton_km                        185 non-null float64
# Air_passengers_carried                            185 non-null float64
# Container_port_traffic_TEU                        183 non-null float64
# Railways_goods_trans_million_ton-km               89 non-null float64
# Logistic_performance                              87 non-null float64
# Industry_value_added_current_USD                  179 non-null float64
# Manufacturing_value added_%_of_GDP                184 non-null float64
# Services_value_added_%_of_GDP                     179 non-null float64
# Employment_in_industry_%_of_total_employment      185 non-null float64
# GDP_per_capita_current_USD                        184 non-null float64
# Final_consumption                                 183 non-null float64
# Primary_completion_rate                           118 non-null float64
# Educational_attainment                            99 non-null float64
# High_technology_exports_current_USD               145 non-null float64
# Trademark_applications_total                      177 non-null float64
# Patent_applications                               175 non-null float64
# Scientific_technical_journal_articles             185 non-null float64
# Research_and_development_expenditure_%_of_GDP     132 non-null float64
# Individuals_using_the_Internet_%_of_population    181 non-null float64
# Poverty_headcount_ratio                           119 non-null float64
# Listed_companies                                  176 non-null float64
# Business_disclosure                               185 non-null int64
# Ease_of_doing_business                            63 non-null float64
# Start_up_procedure                                153 non-null float64
# Cost_of_business_start_up                         185 non-null float64
# Time_to_start_business                            153 non-null float64
# New_business_density                              185 non-null float64
# dtypes: float64(26), int64(2), object(3)
# memory usage: 44.9+ KB

# %%
plt.hist((df['New_business_density']), color = '#1f77b4')
plt.xlim(0,30)
plt.ylim(0,100)
plt.xlabel('No of Business',fontsize=12)
plt.ylabel('No of Country', fontsize=12)
plt.title("New Business Density in Developing Countries")
plt.show()

# %%
df["New_business_density"].describe()
# Out:
# count    185.000000
# mean       2.487582
# std        2.837736
# min        0.041292
# 25%        0.326716
# 50%        1.178486
# 75%        3.951467
# max       10.911789
# Name: New_business_density, dtype: float64

# %%
imp = IterativeImputer(max_iter=10, random_state=0)

# %%
df = df.drop(df.columns[[0, 1, 2, 3]], axis=1)

# %%
df.head()
# Out:
#    Air_freight_million_ton_km  Air_passengers_carried  \
# 0                  124.583000            6.611915e+06
# 1                  132.675000            7.036784e+06
# 2                  131.685000            6.147290e+06
# 3                  111.663000            5.694547e+06
# 4                  193.301254            9.025035e+06
#
#    Container_port_traffic_TEU  Railways_goods_trans_million_ton-km  \
# 0                1.757990e+06                                  NaN
# 1                1.874259e+06                                  NaN
# 2                1.997146e+06                                  NaN
# 3                1.626835e+06                                  NaN
# 4                1.992124e+06                                  NaN
#
#    Logistic_performance  Industry_value_added_current_USD  \
# 0                   NaN                      6.791435e+10
# 1                  2.81                      7.882717e+10
# 2                   NaN                      9.499019e+10
# 3                   NaN                      8.419046e+10
# 4                  2.75                      1.070031e+11
#
#    Manufacturing_value added_%_of_GDP  Services_value_added_%_of_GDP  \
# 0                           17.877794                      48.749133
# 1                           17.047415                      49.508331
# 2                           16.538366                      50.255192
# 3                           15.583777                      53.306001
# 4                           15.844861                      51.495180
#
#    Employment_in_industry_%_of_total_employment  GDP_per_capita_current_USD  \
# 0                                     23.673000                 5919.012037
# 1                                     23.847000                 7245.448317
# 2                                     24.021000                 9020.873098
# 3                                     23.190001                 8225.137176
# 4                                     23.340000                10385.964432
#
#    ...  Research_and_development_expenditure_%_of_GDP  \
# 0  ...                                        0.45216
# 1  ...                                        0.46007
# 2  ...                                        0.47055
# 3  ...                                        0.58398
# 4  ...                                        0.56104
#
#    Individuals_using_the_Internet_%_of_population  Poverty_headcount_ratio  \
# 0                                       20.927202                      3.2
# 1                                       25.946633                      2.6
# 2                                       28.112623                      2.6
# 3                                       34.000000                      2.5
# 4                                       45.000000                      2.2
#
#    Listed_companies  Business_disclosure  Ease_of_doing_business  \
# 0             101.0                    7                     NaN
# 1             106.0                    7                     NaN
# 2             107.0                    7                     NaN
# 3             101.0                    7                     NaN
# 4             101.0                    7                     NaN
#
#    Start_up_procedure  Cost_of_business_start_up  Time_to_start_business  \
# 0                13.0                       18.8                    29.5
# 1                13.0                       15.9                    29.5
# 2                14.0                       12.4                    30.0
# 3                14.0                        9.8                    25.0
# 4                14.0                        9.1                    24.5
#
#    New_business_density
# 0              0.240650
# 1              0.240467
# 2              0.237290
# 3              0.189667
# 4              0.207609
#
# [5 rows x 27 columns]

# %%
data=imp.fit_transform(df)

# %%
print(data)
# Out:
# [[1.24583000e+02 6.61191500e+06 1.75799000e+06 ... 1.88000000e+01
#   2.95000000e+01 2.40650412e-01]
#  [1.32675000e+02 7.03678400e+06 1.87425900e+06 ... 1.59000000e+01
#   2.95000000e+01 2.40466755e-01]
#  [1.31685000e+02 6.14729000e+06 1.99714600e+06 ... 1.24000000e+01
#   3.00000000e+01 2.37290147e-01]
#  ...
#  [1.04273626e+03 1.70266432e+07 4.56799300e+06 ... 0.00000000e+00
#   4.60000000e+01 6.57481813e+00]
#  [8.92734324e+02 1.88828980e+07 4.66230000e+06 ... 0.00000000e+00
#   4.60000000e+01 8.67781982e+00]
#  [7.67271186e+02 1.97449320e+07 4.45400000e+06 ... 0.00000000e+00
#   4.50000000e+01 1.02077982e+01]]

# %%
 dataset=pd.DataFrame({'Air_freight': data[:, 0], 'Air_passenger': data[:, 1], 'Container_traffic': data[:, 2], 'Railway_transport': data[:, 3],
                       'Logistic_performance': data[:, 4], 'Industry_valueadded': data[:, 5],'Mfg_valueadded': data[:, 6], 'Service_valueadded': data[:, 7],
                       'Emp_in_industry': data[:, 8], 'GDP_per_capita': data[:, 9],'Final_consumption': data[:, 10], 'Primary_completion': data[:, 11],
                       'Edu_attainment': data[:, 12], 'Hightech_export': data[:, 13],'Treadmark_appl': data[:, 14], 'Patent_appl': data[:, 15],
                       'Scientific_journal': data[:, 16], 'R&D_exp': data[:, 17],'Individual_using_internet': data[:, 18], 'Poverty_headcount': data[:, 19],
                      'Listed_companies': data[:, 20],'Business_disclosure': data[:, 21],'Ease_of_doing_business': data[:, 22],
                       'Start_up_procedure': data[:, 23],'Cost_of_business': data[:, 24],
                      'Time_to_start_business': data[:, 25],'New_business_density': data[:, 26]})

# %%
dataset.head()
# Out:
#    Air_freight  Air_passenger  Container_traffic  Railway_transport  \
# 0   124.583000   6.611915e+06       1.757990e+06     -178589.291452
# 1   132.675000   7.036784e+06       1.874259e+06     -222738.773765
# 2   131.685000   6.147290e+06       1.997146e+06     -324623.482676
# 3   111.663000   5.694547e+06       1.626835e+06     -300597.648005
# 4   193.301254   9.025035e+06       1.992124e+06     -356834.545588
#
#    Logistic_performance  Industry_valueadded  Mfg_valueadded  \
# 0              2.817401         6.791435e+10       17.877794
# 1              2.810000         7.882717e+10       17.047415
# 2              2.874710         9.499019e+10       16.538366
# 3              2.871134         8.419046e+10       15.583777
# 4              2.750000         1.070031e+11       15.844861
#
#    Service_valueadded  Emp_in_industry  GDP_per_capita  ...  R&D_exp  \
# 0           48.749133        23.673000     5919.012037  ...  0.45216
# 1           49.508331        23.847000     7245.448317  ...  0.46007
# 2           50.255192        24.021000     9020.873098  ...  0.47055
# 3           53.306001        23.190001     8225.137176  ...  0.58398
# 4           51.495180        23.340000    10385.964432  ...  0.56104
#
#    Individual_using_internet  Poverty_headcount  Listed_companies  \
# 0                  20.927202                3.2             101.0
# 1                  25.946633                2.6             106.0
# 2                  28.112623                2.6             107.0
# 3                  34.000000                2.5             101.0
# 4                  45.000000                2.2             101.0
#
#    Business_disclosure  Ease_of_doing_business  Start_up_procedure  \
# 0                  7.0               44.868393                13.0
# 1                  7.0               45.589215                13.0
# 2                  7.0               42.192366                14.0
# 3                  7.0               45.069923                14.0
# 4                  7.0               48.402036                14.0
#
#    Cost_of_business  Time_to_start_business  New_business_density
# 0              18.8                    29.5              0.240650
# 1              15.9                    29.5              0.240467
# 2              12.4                    30.0              0.237290
# 3               9.8                    25.0              0.189667
# 4               9.1                    24.5              0.207609
#
# [5 rows x 27 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 27 columns):
# Air_freight                  185 non-null float64
# Air_passenger                185 non-null float64
# Container_traffic            185 non-null float64
# Railway_transport            185 non-null float64
# Logistic_performance         185 non-null float64
# Industry_valueadded          185 non-null float64
# Mfg_valueadded               185 non-null float64
# Service_valueadded           185 non-null float64
# Emp_in_industry              185 non-null float64
# GDP_per_capita               185 non-null float64
# Final_consumption            185 non-null float64
# Primary_completion           185 non-null float64
# Edu_attainment               185 non-null float64
# Hightech_export              185 non-null float64
# Treadmark_appl               185 non-null float64
# Patent_appl                  185 non-null float64
# Scientific_journal           185 non-null float64
# R&D_exp                      185 non-null float64
# Individual_using_internet    185 non-null float64
# Poverty_headcount            185 non-null float64
# Listed_companies             185 non-null float64
# Business_disclosure          185 non-null float64
# Ease_of_doing_business       185 non-null float64
# Start_up_procedure           185 non-null float64
# Cost_of_business             185 non-null float64
# Time_to_start_business       185 non-null float64
# New_business_density         185 non-null float64
# dtypes: float64(27)
# memory usage: 39.1 KB

# %%
# data visualization
# bulding the correlation matrix
sns.heatmap(dataset.corr())

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
print(dataset[['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport',
                       'Logistic_performance', 'Industry_valueadded','Mfg_valueadded', 'Service_valueadded',
                       'Emp_in_industry', 'GDP_per_capita','Final_consumption', 'Primary_completion',
                       'Edu_attainment', 'Hightech_export','Treadmark_appl', 'Patent_appl',
                       'Scientific_journal', 'R&D_exp','Individual_using_internet', 'Poverty_headcount',
                      'Listed_companies','Business_disclosure','Ease_of_doing_business',
                       'Start_up_procedure','Cost_of_business',
                      'Time_to_start_business']].corr())
# Out:
#                            Air_freight  Air_passenger  Container_traffic  \
# Air_freight                   1.000000       0.382523           0.149313
# Air_passenger                 0.382523       1.000000           0.621709
# Container_traffic             0.149313       0.621709           1.000000
# Railway_transport             0.104311       0.348623           0.132611
# Logistic_performance          0.311182       0.145214           0.430311
# Industry_valueadded           0.243757       0.769716           0.311645
# Mfg_valueadded               -0.191354      -0.046214           0.391900
# Service_valueadded           -0.255579       0.003839          -0.075986
# Emp_in_industry               0.467014      -0.240734          -0.308616
# GDP_per_capita                0.501456      -0.172827          -0.282855
# Final_consumption             0.165206       0.780154           0.275709
# Primary_completion           -0.211075      -0.195283           0.047075
# Edu_attainment                0.233710      -0.160686          -0.258909
# Hightech_export               0.006661       0.157614           0.602048
# Treadmark_appl                0.084890       0.768184           0.375218
# Patent_appl                   0.389884       0.433332           0.038660
# Scientific_journal            0.196037       0.699213           0.314683
# R&D_exp                       0.297662       0.393269           0.363734
# Individual_using_internet     0.396549       0.000576          -0.026371
# Poverty_headcount            -0.518145       0.122098           0.173055
# Listed_companies              0.032421       0.436706           0.367946
# Business_disclosure          -0.209703      -0.005858           0.263042
# Ease_of_doing_business        0.257829       0.139253           0.203418
# Start_up_procedure           -0.171796       0.155975           0.137813
# Cost_of_business             -0.038058       0.017794          -0.030943
# Time_to_start_business       -0.257737       0.124335           0.039018
#
#                            Railway_transport  Logistic_performance  \
# Air_freight                         0.104311              0.311182
# Air_passenger                       0.348623              0.145214
# Container_traffic                   0.132611              0.430311
# Railway_transport                   1.000000             -0.415877
# Logistic_performance               -0.415877              1.000000
# Industry_valueadded                 0.567630             -0.128754
# Mfg_valueadded                      0.022629              0.085759
# Service_valueadded                  0.297442             -0.024784
# Emp_in_industry                    -0.406086              0.178751
# GDP_per_capita                     -0.540897              0.190894
# Final_consumption                   0.471661             -0.069510
# Primary_completion                 -0.082154             -0.092741
# Edu_attainment                      0.120872             -0.150696
# Hightech_export                    -0.010128              0.291979
# Treadmark_appl                      0.256057              0.088137
# Patent_appl                         0.842991             -0.368513
# Scientific_journal                  0.498602              0.030866
# R&D_exp                             0.335963              0.223615
# Individual_using_internet          -0.172013              0.282813
# Poverty_headcount                   0.365753             -0.206951
# Listed_companies                    0.245638              0.097153
# Business_disclosure                 0.048476              0.183077
# Ease_of_doing_business              0.130312              0.204473
# Start_up_procedure                 -0.153719             -0.101752
# Cost_of_business                   -0.070642             -0.078015
# Time_to_start_business              0.023024              0.075581
#
#                            Industry_valueadded  Mfg_valueadded  \
# Air_freight                           0.243757       -0.191354
# Air_passenger                         0.769716       -0.046214
# Container_traffic                     0.311645        0.391900
# Railway_transport                     0.567630        0.022629
# Logistic_performance                 -0.128754        0.085759
# Industry_valueadded                   1.000000       -0.227588
# Mfg_valueadded                       -0.227588        1.000000
# Service_valueadded                    0.015931       -0.173516
# Emp_in_industry                      -0.210651       -0.422473
# GDP_per_capita                       -0.167631       -0.433121
# Final_consumption                     0.900419       -0.323234
# Primary_completion                   -0.078148        0.142890
# Edu_attainment                       -0.128120       -0.259139
# Hightech_export                       0.087180        0.418903
# Treadmark_appl                        0.784834       -0.187750
# Patent_appl                           0.664926       -0.294672
# Scientific_journal                    0.762131       -0.267932
# R&D_exp                               0.356172       -0.344021
# Individual_using_internet            -0.142755       -0.408536
# Poverty_headcount                     0.208539        0.283819
# Listed_companies                      0.508711        0.030833
# Business_disclosure                  -0.092647        0.429533
# Ease_of_doing_business                0.000828       -0.008476
# Start_up_procedure                    0.078678        0.099554
# Cost_of_business                      0.160055       -0.066701
# Time_to_start_business                0.177390       -0.198577
#
#                            Service_valueadded  Emp_in_industry  \
# Air_freight                         -0.255579         0.467014
# Air_passenger                        0.003839        -0.240734
# Container_traffic                   -0.075986        -0.308616
# Railway_transport                    0.297442        -0.406086
# Logistic_performance                -0.024784         0.178751
# Industry_valueadded                  0.015931        -0.210651
# Mfg_valueadded                      -0.173516        -0.422473
# Service_valueadded                   1.000000        -0.466304
# Emp_in_industry                     -0.466304         1.000000
# GDP_per_capita                      -0.540918         0.882253
# Final_consumption                    0.224793        -0.271917
# Primary_completion                   0.024023        -0.006840
# Edu_attainment                       0.079163         0.321983
# Hightech_export                      0.094039        -0.147030
# Treadmark_appl                       0.110558        -0.299031
# Patent_appl                          0.041071        -0.003054
# Scientific_journal                   0.091596        -0.129009
# R&D_exp                              0.228610         0.142932
# Individual_using_internet            0.151357         0.491235
# Poverty_headcount                    0.254878        -0.805888
# Listed_companies                    -0.220415        -0.156448
# Business_disclosure                 -0.025982        -0.073324
# Ease_of_doing_business               0.108422         0.350559
# Start_up_procedure                  -0.172388        -0.381859
# Cost_of_business                    -0.432216         0.119737
# Time_to_start_business               0.374297        -0.302096
#
#                            GDP_per_capita  ...  Scientific_journal   R&D_exp  \
# Air_freight                      0.501456  ...            0.196037  0.297662
# Air_passenger                   -0.172827  ...            0.699213  0.393269
# Container_traffic               -0.282855  ...            0.314683  0.363734
# Railway_transport               -0.540897  ...            0.498602  0.335963
# Logistic_performance             0.190894  ...            0.030866  0.223615
# Industry_valueadded             -0.167631  ...            0.762131  0.356172
# Mfg_valueadded                  -0.433121  ...           -0.267932 -0.344021
# Service_valueadded              -0.540918  ...            0.091596  0.228610
# Emp_in_industry                  0.882253  ...           -0.129009  0.142932
# GDP_per_capita                   1.000000  ...           -0.203502  0.005498
# Final_consumption               -0.227408  ...            0.807644  0.507268
# Primary_completion              -0.044860  ...           -0.266079 -0.179866
# Edu_attainment                   0.356730  ...            0.096129  0.118825
# Hightech_export                 -0.134961  ...           -0.012329  0.108643
# Treadmark_appl                  -0.264427  ...            0.819287  0.316559
# Patent_appl                     -0.075393  ...            0.622220  0.487004
# Scientific_journal              -0.203502  ...            1.000000  0.533592
# R&D_exp                          0.005498  ...            0.533592  1.000000
# Individual_using_internet        0.484981  ...            0.005247  0.350504
# Poverty_headcount               -0.804360  ...            0.185131 -0.133431
# Listed_companies                -0.228532  ...            0.722459  0.203260
# Business_disclosure             -0.312134  ...           -0.099289  0.035465
# Ease_of_doing_business           0.141069  ...            0.156503  0.413330
# Start_up_procedure              -0.158198  ...            0.052527 -0.320600
# Cost_of_business                 0.130983  ...            0.194581 -0.026905
# Time_to_start_business          -0.255786  ...            0.178220  0.137181
#
#                            Individual_using_internet  Poverty_headcount  \
# Air_freight                                 0.396549          -0.518145
# Air_passenger                               0.000576           0.122098
# Container_traffic                          -0.026371           0.173055
# Railway_transport                          -0.172013           0.365753
# Logistic_performance                        0.282813          -0.206951
# Industry_valueadded                        -0.142755           0.208539
# Mfg_valueadded                             -0.408536           0.283819
# Service_valueadded                          0.151357           0.254878
# Emp_in_industry                             0.491235          -0.805888
# GDP_per_capita                              0.484981          -0.804360
# Final_consumption                          -0.070839           0.222247
# Primary_completion                         -0.014913          -0.064383
# Edu_attainment                              0.474833          -0.521727
# Hightech_export                             0.044338          -0.017726
# Treadmark_appl                             -0.176478           0.276325
# Patent_appl                                 0.060967          -0.013696
# Scientific_journal                          0.005247           0.185131
# R&D_exp                                     0.350504          -0.133431
# Individual_using_internet                   1.000000          -0.635015
# Poverty_headcount                          -0.635015           1.000000
# Listed_companies                           -0.356383           0.386850
# Business_disclosure                        -0.096346           0.124139
# Ease_of_doing_business                      0.695322          -0.427864
# Start_up_procedure                         -0.383261           0.295903
# Cost_of_business                           -0.302704           0.198947
# Time_to_start_business                     -0.179599           0.210051
#
#                            Listed_companies  Business_disclosure  \
# Air_freight                        0.032421            -0.209703
# Air_passenger                      0.436706            -0.005858
# Container_traffic                  0.367946             0.263042
# Railway_transport                  0.245638             0.048476
# Logistic_performance               0.097153             0.183077
# Industry_valueadded                0.508711            -0.092647
# Mfg_valueadded                     0.030833             0.429533
# Service_valueadded                -0.220415            -0.025982
# Emp_in_industry                   -0.156448            -0.073324
# GDP_per_capita                    -0.228532            -0.312134
# Final_consumption                  0.430244            -0.168511
# Primary_completion                -0.105379             0.195605
# Edu_attainment                    -0.150696            -0.522274
# Hightech_export                    0.071903             0.220535
# Treadmark_appl                     0.661658            -0.059126
# Patent_appl                        0.271256            -0.171258
# Scientific_journal                 0.722459            -0.099289
# R&D_exp                            0.203260             0.035465
# Individual_using_internet         -0.356383            -0.096346
# Poverty_headcount                  0.386850             0.124139
# Listed_companies                   1.000000            -0.024289
# Business_disclosure               -0.024289             1.000000
# Ease_of_doing_business            -0.059471             0.344085
# Start_up_procedure                 0.341071            -0.483923
# Cost_of_business                   0.544977            -0.142221
# Time_to_start_business             0.049542            -0.138019
#
#                            Ease_of_doing_business  Start_up_procedure  \
# Air_freight                              0.257829           -0.171796
# Air_passenger                            0.139253            0.155975
# Container_traffic                        0.203418            0.137813
# Railway_transport                        0.130312           -0.153719
# Logistic_performance                     0.204473           -0.101752
# Industry_valueadded                      0.000828            0.078678
# Mfg_valueadded                          -0.008476            0.099554
# Service_valueadded                       0.108422           -0.172388
# Emp_in_industry                          0.350559           -0.381859
# GDP_per_capita                           0.141069           -0.158198
# Final_consumption                       -0.034047            0.099605
# Primary_completion                       0.040445           -0.007572
# Edu_attainment                           0.295504           -0.043363
# Hightech_export                          0.271206           -0.108305
# Treadmark_appl                          -0.120413            0.301919
# Patent_appl                              0.170726           -0.172310
# Scientific_journal                       0.156503            0.052527
# R&D_exp                                  0.413330           -0.320600
# Individual_using_internet                0.695322           -0.383261
# Poverty_headcount                       -0.427864            0.295903
# Listed_companies                        -0.059471            0.341071
# Business_disclosure                      0.344085           -0.483923
# Ease_of_doing_business                   1.000000           -0.547936
# Start_up_procedure                      -0.547936            1.000000
# Cost_of_business                        -0.083260            0.370970
# Time_to_start_business                  -0.283807            0.190678
#
#                            Cost_of_business  Time_to_start_business
# Air_freight                       -0.038058               -0.257737
# Air_passenger                      0.017794                0.124335
# Container_traffic                 -0.030943                0.039018
# Railway_transport                 -0.070642                0.023024
# Logistic_performance              -0.078015                0.075581
# Industry_valueadded                0.160055                0.177390
# Mfg_valueadded                    -0.066701               -0.198577
# Service_valueadded                -0.432216                0.374297
# Emp_in_industry                    0.119737               -0.302096
# GDP_per_capita                     0.130983               -0.255786
# Final_consumption                  0.081382                0.356020
# Primary_completion                -0.121498               -0.177079
# Edu_attainment                    -0.145021               -0.212466
# Hightech_export                   -0.094119               -0.191811
# Treadmark_appl                     0.159704                0.218076
# Patent_appl                        0.016938               -0.043594
# Scientific_journal                 0.194581                0.178220
# R&D_exp                           -0.026905                0.137181
# Individual_using_internet         -0.302704               -0.179599
# Poverty_headcount                  0.198947                0.210051
# Listed_companies                   0.544977                0.049542
# Business_disclosure               -0.142221               -0.138019
# Ease_of_doing_business            -0.083260               -0.283807
# Start_up_procedure                 0.370970                0.190678
# Cost_of_business                   1.000000                0.008805
# Time_to_start_business             0.008805                1.000000
#
# [26 rows x 26 columns]

# %%
#Correlation with output variable
cor_target = abs(cor["New_business_density"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Start_up_procedure      0.528763
# New_business_density    1.000000
# Name: New_business_density, dtype: float64

# %%
#Correlation with output variable
cor_target = abs(cor["New_business_density"])
#Selecting all correlated features
relevant_features = cor_target[cor_target> -1]
relevant_features
# Out:
# Air_freight                  0.050351
# Air_passenger                0.339680
# Container_traffic            0.317652
# Railway_transport            0.026195
# Logistic_performance         0.031718
# Industry_valueadded          0.352842
# Mfg_valueadded               0.331170
# Service_valueadded           0.147757
# Emp_in_industry              0.377145
# GDP_per_capita               0.172062
# Final_consumption            0.297024
# Primary_completion           0.166007
# Edu_attainment               0.010222
# Hightech_export              0.306625
# Treadmark_appl               0.396537
# Patent_appl                  0.016021
# Scientific_journal           0.220897
# R&D_exp                      0.194468
# Individual_using_internet    0.230551
# Poverty_headcount            0.187371
# Listed_companies             0.287120
# Business_disclosure          0.212802
# Ease_of_doing_business       0.246531
# Start_up_procedure           0.528763
# Cost_of_business             0.212820
# Time_to_start_business       0.034730
# New_business_density         1.000000
# Name: New_business_density, dtype: float64

# %%
x=dataset[['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport',
                       'Logistic_performance', 'Industry_valueadded','Mfg_valueadded', 'Service_valueadded',
                       'Emp_in_industry', 'GDP_per_capita','Final_consumption', 'Primary_completion',
                       'Edu_attainment', 'Hightech_export','Treadmark_appl', 'Patent_appl',
                       'Scientific_journal', 'R&D_exp','Individual_using_internet', 'Poverty_headcount',
                      'Listed_companies','Business_disclosure','Ease_of_doing_business',
                       'Start_up_procedure','Cost_of_business',
                      'Time_to_start_business']]
y=dataset['New_business_density']

# %%
#Backward Elimination
cols = list(x.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['Air_freight', 'Air_passenger', 'Container_traffic', 'Railway_transport', 'Industry_valueadded', 'Mfg_valueadded', 'GDP_per_capita', 'Hightech_export', 'Treadmark_appl', 'Individual_using_internet', 'Poverty_headcount', 'Listed_companies', 'Ease_of_doing_business', 'Start_up_procedure', 'Cost_of_business', 'Time_to_start_business']
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
#no of features
nof_list=np.arange(1,26)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 25
# Score with 25 features: 0.768020

# %%
cols = list(x.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 25)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(x,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['Air_freight', 'Air_passenger', 'Container_traffic',
#        'Railway_transport', 'Logistic_performance', 'Industry_valueadded',
#        'Mfg_valueadded', 'Service_valueadded', 'Emp_in_industry',
#        'GDP_per_capita', 'Primary_completion', 'Edu_attainment',
#        'Hightech_export', 'Treadmark_appl', 'Patent_appl',
#        'Scientific_journal', 'R&D_exp', 'Individual_using_internet',
#        'Poverty_headcount', 'Listed_companies', 'Business_disclosure',
#        'Ease_of_doing_business', 'Start_up_procedure', 'Cost_of_business',
#        'Time_to_start_business'],
#       dtype='object')

# %%
est = sm.OLS(y, x)
est2 = est.fit()
print(est2.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     New_business_density   R-squared:                       0.844
# Model:                              OLS   Adj. R-squared:                  0.820
# Method:                   Least Squares   F-statistic:                     34.43
# Date:                  Thu, 06 Aug 2020   Prob (F-statistic):           1.24e-51
# Time:                          22:14:43   Log-Likelihood:                -283.06
# No. Observations:                   185   AIC:                             618.1
# Df Residuals:                       159   BIC:                             701.8
# Df Model:                            25
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Air_freight                   0.0006      0.000      3.674      0.000       0.000       0.001
# Air_passenger             -7.963e-08   1.38e-08     -5.754      0.000   -1.07e-07   -5.23e-08
# Container_traffic          1.825e-07    6.6e-08      2.766      0.006    5.22e-08    3.13e-07
# Railway_transport          5.446e-06   1.18e-06      4.605      0.000    3.11e-06    7.78e-06
# Logistic_performance         -1.0481      0.569     -1.843      0.067      -2.171       0.075
# Industry_valueadded       -1.934e-11   2.64e-12     -7.321      0.000   -2.46e-11   -1.41e-11
# Mfg_valueadded               -0.4344      0.048     -8.986      0.000      -0.530      -0.339
# Service_valueadded           -0.0446      0.041     -1.097      0.274      -0.125       0.036
# Emp_in_industry              -0.0667      0.045     -1.478      0.141      -0.156       0.022
# GDP_per_capita                0.0004    4.1e-05      8.761      0.000       0.000       0.000
# Final_consumption         -6.989e-13   1.27e-12     -0.550      0.583   -3.21e-12    1.81e-12
# Primary_completion           -0.1197      0.023     -5.121      0.000      -0.166      -0.074
# Edu_attainment               -0.1000      0.057     -1.753      0.082      -0.213       0.013
# Hightech_export           -2.719e-11   1.15e-11     -2.356      0.020      -5e-11    -4.4e-12
# Treadmark_appl             6.456e-05   1.11e-05      5.793      0.000    4.26e-05    8.66e-05
# Patent_appl                  -0.0003   8.66e-05     -3.048      0.003      -0.000   -9.29e-05
# Scientific_journal        -8.727e-06   2.13e-05     -0.410      0.682   -5.08e-05    3.33e-05
# R&D_exp                       1.1011      0.748      1.472      0.143      -0.377       2.579
# Individual_using_internet    -0.1976      0.019    -10.452      0.000      -0.235      -0.160
# Poverty_headcount             0.3536      0.042      8.518      0.000       0.272       0.436
# Listed_companies             -0.0011      0.000     -3.556      0.000      -0.002      -0.001
# Business_disclosure           0.0294      0.109      0.270      0.787      -0.186       0.245
# Ease_of_doing_business        0.5515      0.052     10.513      0.000       0.448       0.655
# Start_up_procedure            0.2407      0.082      2.947      0.004       0.079       0.402
# Cost_of_business             -0.0488      0.004    -11.339      0.000      -0.057      -0.040
# Time_to_start_business        0.0518      0.011      4.633      0.000       0.030       0.074
# ==============================================================================
# Omnibus:                        0.530   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.265
# Skew:                           0.055   Prob(JB):                        0.876
# Kurtosis:                       3.149   Cond. No.                     6.51e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.51e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Code for VIF Calculation

#Writing a function to calculate the VIF values

def vif_cal(input_data, dependent_col):
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y, x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
#Calculating VIF values using that function
vif_cal(input_data=dataset, dependent_col="New_business_density")
# Out:
# Air_freight  VIF =  12.26
# Air_passenger  VIF =  27.25
# Container_traffic  VIF =  16.42
# Railway_transport  VIF =  88.36
# Logistic_performance  VIF =  3.78
# Industry_valueadded  VIF =  26.72
# Mfg_valueadded  VIF =  8.56
# Service_valueadded  VIF =  11.76
# Emp_in_industry  VIF =  18.92
# GDP_per_capita  VIF =  61.08
# Final_consumption  VIF =  106.72
# Primary_completion  VIF =  1.35
# Edu_attainment  VIF =  12.54
# Hightech_export  VIF =  6.28
# Treadmark_appl  VIF =  56.94
# Patent_appl  VIF =  46.47
# Scientific_journal  VIF =  34.68
# R&D_exp  VIF =  6.97
# Individual_using_internet  VIF =  25.1
# Poverty_headcount  VIF =  20.24
# Listed_companies  VIF =  21.76
# Business_disclosure  VIF =  8.3
# Ease_of_doing_business  VIF =  35.19
# Start_up_procedure  VIF =  10.44
# Cost_of_business  VIF =  6.48
# Time_to_start_business  VIF =  4.78

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
lm.fit(train_x,train_y)
ypred = lm.predict(test_x)
print ('Coefficients: ', lm.coef_)
print('Variance score: %.2f' % lm.score(x, y))
print('Variance score: %.2f' % lm.score(train_x, train_y))
print('Variance score: %.2f' % lm.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [ 7.84925623e-04 -1.14180280e-07  3.20455110e-07  5.86908224e-06
#  -1.22193998e+00 -2.56549437e-11 -3.29296411e-01  4.89911946e-02
#  -9.93010260e-03  5.33753628e-04 -1.89024204e-13 -4.26064177e-02
#  -2.66503549e-02 -5.39652447e-11  1.01319021e-04 -1.65198173e-04
#  -3.52637824e-05  6.44330316e-01 -2.61608480e-01  6.09953449e-01
#  -1.86163678e-03  1.38275029e-01  7.64469154e-01  4.28245704e-01
#  -5.93497972e-02  8.84746169e-02]
# Variance score: 0.85
# Variance score: 0.89
# Variance score: 0.66
# R2 Score: 0.66

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Linear Regression")
plt.show()

# %%
lm_lasso.fit(train_x,train_y)
ypred = lm_lasso.predict(test_x)
print ('Coefficients: ', lm_lasso.coef_)
print('Variance score: %.2f' % lm_lasso.score(x, y))
print('Variance score: %.2f' % lm_lasso.score(train_x, train_y))
print('Variance score: %.2f' % lm_lasso.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [-3.53608323e-04 -4.63343845e-09  1.50023171e-08  9.86060971e-06
#   0.00000000e+00 -2.54125357e-11 -1.95835877e-01  1.61359211e-02
#   0.00000000e+00  2.79686606e-04  4.05304565e-12 -7.96400486e-02
#  -2.25706061e-01 -2.56269533e-11  1.96026594e-05 -5.49351242e-04
#  -4.97651627e-05  0.00000000e+00 -3.97353665e-02  0.00000000e+00
#   1.02890489e-03  0.00000000e+00  1.49578442e-01 -0.00000000e+00
#  -2.50600192e-02  5.75538565e-03]
# Variance score: 0.73
# Variance score: 0.78
# Variance score: 0.50
# R2 Score: 0.50
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224.66165012486283, tolerance: 0.11838411331385483
#   positive)

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("LASSO Regression")
plt.show()

# %%
lm_ridge.fit(train_x,train_y)
ypred = lm_ridge.predict(test_x)
print ('Coefficients: ', lm_ridge.coef_)
print('Variance score: %.2f' % lm_ridge.score(x, y))
print('Variance score: %.2f' % lm_ridge.score(train_x, train_y))
print('Variance score: %.2f' % lm_ridge.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Coefficients:  [ 7.47600806e-04 -1.12551530e-07  3.18269334e-07  5.94105625e-06
#  -9.18188070e-01 -2.60384261e-11 -3.31979094e-01  4.81758465e-02
#  -3.72817573e-03  5.27393712e-04  1.45315185e-13 -4.37894173e-02
#  -3.08881180e-02 -5.33266455e-11  9.92210461e-05 -1.60373069e-04
#  -3.68617232e-05  3.83231775e-01 -2.58495923e-01  6.00104461e-01
#  -1.81236232e-03  1.36561968e-01  7.55929783e-01  4.25962365e-01
#  -5.87606978e-02  8.57935284e-02]
# Variance score: 0.85
# Variance score: 0.89
# Variance score: 0.67
# R2 Score: 0.67
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.48336e-26): result may not be accurate.
#   overwrite_a=True).T

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Ridge Regression")
plt.show()

# %%
alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]

# %%
for a in alphas:
    model = ElasticNet(alpha=a).fit(x,y)   
    score = model.score(x, y)
    pred_y = model.predict(x)
    mse = mean_squared_error(y, pred_y)   
    print("Alpha:{0:.4f}, R2:{1:.2f}, MSE:{2:.2f}, RMSE:{3:.2f}"
       .format(a, score, mse, np.sqrt(mse)))
# Out:
# Alpha:0.0001, R2:0.87, MSE:1.07, RMSE:1.03
# Alpha:0.0010, R2:0.87, MSE:1.07, RMSE:1.03
# Alpha:0.0100, R2:0.87, MSE:1.07, RMSE:1.04
# Alpha:0.1000, R2:0.86, MSE:1.13, RMSE:1.06
# Alpha:0.3000, R2:0.84, MSE:1.31, RMSE:1.14
# Alpha:0.5000, R2:0.82, MSE:1.42, RMSE:1.19
# Alpha:0.7000, R2:0.81, MSE:1.52, RMSE:1.23
# Alpha:1.0000, R2:0.79, MSE:1.68, RMSE:1.30
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.76152431447532, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99.18275722346414, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.92204222687974, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128.87751077473723, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168.5471259779281, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196.5336337787478, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221.081329471474, tolerance: 0.14817050128320455
#   positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 252.8626604094569, tolerance: 0.14817050128320455
#   positive)

# %%
elastic=ElasticNet(alpha=0.01).fit(train_x, train_y)
ypred = elastic.predict(test_x)
score = elastic.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.668, MSE:1.66, RMSE:1.29
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.19407926581532, tolerance: 0.11838411331385483
#   positive)

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Elastic Net Regression")
plt.show()

# %%
elastic_cv=ElasticNetCV(alphas=alphas, cv=5)
model = elastic_cv.fit(train_x, train_y)
print(model.alpha_)
print(model.intercept_)
# Out:
# 0.01
# -32.73763107712779
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128.19333747674597, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.27370212709987, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.41032405815068, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.85554676576831, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.310305746983516, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.28686988814904, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.92085206966942, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.65360458172662, tolerance: 0.10282917130066067
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.64323229542273, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.18445841250065, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.4667512486999, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87.32534364532863, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.25721406204131, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.74509378015851, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.25111175638954, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.97009502381624, tolerance: 0.10073290292627463
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136.6740729484702, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.18406927406265, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.68600746568707, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.36641086938685, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.59200841514644, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.7355496925858, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.425487677919904, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.02028018797165, tolerance: 0.0888464708388559
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.95811999781358, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.56779518458762, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101.17747791529781, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86.93054145187075, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.85840397206026, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.12100062250527, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.212107271735256, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.838465064484076, tolerance: 0.08662721706455787
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140.3650971861481, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.10931785111298, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.75760839603721, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87.56216629961014, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.83226771104248, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.82288245021066, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.42944009878266, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.14630024890542, tolerance: 0.09370525716331035
#   tol, rng, random, positive)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.19407926581532, tolerance: 0.11838411331385483
#   positive)

# %%
ypred = model.predict(test_x)
score = model.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.668, MSE:1.66, RMSE:1.29

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Elastic Net Regression")
plt.show()

# %%
lm_elastic.fit(train_x,train_y)
print ('Coefficients: ', lm_elastic.coef_)
print('Variance score: %.2f' % lm_elastic.score(x, y))
# Out:
# Coefficients:  [-2.30540355e-04 -1.68379788e-08  7.84210611e-08  9.08713781e-06
#  -0.00000000e+00 -2.47584930e-11 -2.24541027e-01  4.03685161e-02
#   2.67093380e-02  3.04377623e-04  3.05795999e-12 -9.60073154e-02
#  -1.88317655e-01 -3.21081057e-11  3.44450845e-05 -4.68864822e-04
#  -6.19696105e-05  0.00000000e+00 -7.38353742e-02  8.85157883e-02
#   6.82202723e-04  0.00000000e+00  2.33532406e-01 -0.00000000e+00
#  -2.87623136e-02  1.77121128e-02]
# Variance score: 0.77
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174.09648420292217, tolerance: 0.11838411331385483
#   positive)

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(train_x, train_y)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % neigh.score(x, y))
print('Variance score: %.2f' % neigh.score(train_x, train_y))
print('Variance score: %.2f' % neigh.score(test_x, test_y))
print('R2 Score: %.2f' % r2_score(test_y, ypred))
# Out:
# Variance score: 0.68
# Variance score: 0.73
# Variance score: 0.42
# R2 Score: 0.67

# %%
model = neigh.fit(train_x, train_y)
ypred = model.predict(test_x)
score = model.score(test_x, test_y)
mse = mean_squared_error(test_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("K Nearest Neighbor Regression")
plt.show()
# Out:
# R2:0.417, MSE:2.91, RMSE:1.71

# %%
x_norm = (x - x.mean()) / x.std()

# %%
y_norm = (y - y.mean()) / y.std()

# %%
train_norm_x,test_norm_x,train_norm_y,test_norm_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
model_lar = linear_model.Lars(n_nonzero_coefs=15)

# %%
model_lar.fit(train_norm_x, train_norm_y)
ypred=model_lar.predict(test_norm_x)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % model_lar.score(x_norm, y_norm))
print('Variance score: %.2f' % model_lar.score(train_norm_x, train_norm_y))
print('Variance score: %.2f' % model_lar.score(test_norm_x, test_norm_y))
print('R2 Score: %.2f' % r2_score(test_norm_y, ypred))
# Out:
# Variance score: 0.63
# Variance score: 0.65
# Variance score: 0.58
# R2 Score: 0.58

# %%
model = model_lar.fit(train_norm_x, train_norm_y)
ypred = model.predict(test_norm_x)
score = model.score(test_norm_x, test_norm_y)
mse = mean_squared_error(test_norm_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_norm_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_norm_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Least Angle Regression")
plt.show()
# Out:
# R2:0.585, MSE:0.55, RMSE:0.74

# %%
model_ARD = linear_model.ARDRegression()

# %%
model_ARD.fit(train_norm_x, train_norm_y)
ypred=model_ARD.predict(test_norm_x)
#print ('Coefficients: ', neigh.coef_)
print('Variance score: %.2f' % model_ARD.score(x_norm, y_norm))
print('Variance score: %.2f' % model_ARD.score(train_norm_x, train_norm_y))
print('Variance score: %.2f' % model_ARD.score(test_norm_x, test_norm_y))
print('R2 Score: %.2f' % r2_score(test_norm_y, ypred))
# Out:
# Variance score: 0.85
# Variance score: 0.86
# Variance score: 0.82
# R2 Score: 0.82

# %%
model = model_ARD.fit(train_norm_x, train_norm_y)
ypred = model.predict(test_norm_x)
score = model.score(test_norm_x, test_norm_y)
mse = mean_squared_error(test_norm_y, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))
x_ax = range(len(test_norm_x))
#plt.scatter(x_ax, test_y, s=5, color="blue", label="original")
plt.plot(x_ax, test_norm_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim (0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("ARD Regression")
plt.show()
# Out:
# R2:0.821, MSE:0.24, RMSE:0.49

# %%
print("R Square value for Simple Regression Training data is ",np.round(lm.score(train_x, train_y)*100,2))
print("R Square value for Lasso Regression Training data is ",np.round(lm_lasso.score(train_x, train_y)*100,2))
print("R Square value for Ridge Regression Training data is ",np.round(lm_ridge.score(train_x, train_y)*100,2))
print("R Square value for Elastic Net Regression Training data is ",np.round(lm_elastic.score(train_x, train_y)*100,2))
print("R Square value for K Nearest Neighbor Regression Training data is ",np.round(neigh.score(train_x, train_y)*100,2))
print("R Square value for Least Angle Regression Training data is ",np.round(model_lar.score(train_norm_x, train_norm_y)*100,2))
print("R Square value for ARD Regression Training data is ",np.round(model_ARD.score(train_norm_x, train_norm_y)*100,2))
# Out:
# R Square value for Simple Regression Training data is  89.07
# R Square value for Lasso Regression Training data is  78.16
# R Square value for Ridge Regression Training data is  89.04
# R Square value for Elastic Net Regression Training data is  82.61
# R Square value for K Nearest Neighbor Regression Training data is  73.46
# R Square value for Least Angle Regression Training data is  64.98
# R Square value for ARD Regression Training data is  86.34

# %%
print("R Square value for Simple Regression Test data is ",np.round(lm.score(test_x, test_y)*100,2))
print("R Square value for Lasso Regression Test data is ",np.round(lm_lasso.score(test_x, test_y)*100,2))
print("R Square value for Ridge Regression Test data is ",np.round(lm_ridge.score(test_x, test_y)*100,2))
print("R Square value for Elastic Net Regression Test data is ",np.round(lm_elastic.score(test_x, test_y)*100,2))
print("R Square value for K Nearest Neighbor Regression Test data is ",np.round(neigh.score(test_x, test_y)*100,2))
print("R Square value for Least Angle Regression Test data is ",np.round(model_lar.score(test_norm_x, test_norm_y)*100,2))
print("R Square value for ARD Regression Test data is ",np.round(model_ARD.score(test_norm_x, test_norm_y)*100,2))
# Out:
# R Square value for Simple Regression Test data is  66.28
# R Square value for Lasso Regression Test data is  49.94
# R Square value for Ridge Regression Test data is  66.69
# R Square value for Elastic Net Regression Test data is  53.38
# R Square value for K Nearest Neighbor Regression Test data is  41.74
# R Square value for Least Angle Regression Test data is  58.46
# R Square value for ARD Regression Test data is  82.13

# %%
plt.figure(figsize=(15,10))
ft_importance_lm=pd.Series(lm.coef_,index=x.columns)
ft_importance_lm.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_lasso=pd.Series(lm_lasso.coef_,index=x.columns)
ft_importance_lm_lasso.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_ridge=pd.Series(lm_ridge.coef_,index=x.columns)
ft_importance_lm_ridge.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_elastic=pd.Series(lm_elastic.coef_,index=x.columns)
ft_importance_lm_elastic.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_LAR=pd.Series(model_lar.coef_,index=x.columns)
ft_importance_lm_LAR.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,10))
ft_importance_lm_ARD=pd.Series(model_ARD.coef_,index=x.columns)
ft_importance_lm_ARD.plot(kind='barh')
plt.show()

# %%
x_norm = (x - x.mean()) / x.std()

# %%
y_norm = (y - y.mean()) / y.std()

# %%
train_x,test_x,train_y,test_y=train_test_split(x_norm,y_norm,test_size=0.3,random_state=50)

# %%
regressor = DecisionTreeRegressor(random_state=0)

# %%
regressor.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
ypred = regressor.predict(test_x)
score_train = regressor.score(train_x, train_y)
score_test = regressor.score(test_x, test_y)
print("R Square value for Decision Tree Regression Training data is ",(score_train))
print("R Square value for Decision Tree Regression Test data is ",(score_test))
print("R Square value for Decision Tree Regression Test data is ",(r2_score(test_y, ypred)))
# Out:
# R Square value for Decision Tree Regression Training data is  0.999999997921373
# R Square value for Decision Tree Regression Test data is  0.6123506721820691
# R Square value for Decision Tree Regression Test data is  0.6123506721820691

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Decision Tree Regression")
plt.show()

# %%
predictions = regressor.predict(test_x)

# %%
errors = abs(predictions - test_y)

# %%
print('Mean Absolute Error:', round(np.mean(errors), 2), )
# Out:
# Mean Absolute Error: 0.34

# %%
cross_val_score(regressor, x, y, cv=10)
# Out:
# array([-2.71919426,  0.58992652, -5.03141288,  0.72937174, -2.28263315,
#        -4.58739144, -0.02249124, -3.40181659,  0.63726586, -1.90308587])

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 110.43 %.

# %%
# Instantiate model with 100 decision trees
rf = RandomForestRegressor( n_estimators = 100, random_state = 0)
# Train the model on training data
rf.fit(train_x, train_y);

# %%
ypred = rf.predict(test_x)
score_train = rf.score(train_x, train_y)
score_test = rf.score(test_x, test_y)
print("R Square value for Random Forest Regression Training data is ",(score_train))
print("R Square value for Random Forest Regression Test data is ",(score_test))
print("R Square value for Random Forest Regression Test data is ",(r2_score(test_y, ypred)))
# Out:
# R Square value for Random Forest Regression Training data is  0.9790061899297694
# R Square value for Random Forest Regression Test data is  0.8036751154843155
# R Square value for Random Forest Regression Test data is  0.8036751154843155

# %%
x_ax = range(len(test_x))
plt.plot(x_ax, test_y, lw=0.8, color="blue", label="Original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="Predicted")
plt.xlim(0,30)
plt.xlabel(' No of Prediction Instances')
plt.ylabel(' New Business Density')
plt.legend()
plt.title("Random Forest Regression")
plt.show()

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_x)
# Calculate the absolute errors
errors = abs(predictions - test_y)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2),)
# Out:
# Mean Absolute Error: 0.27

# %%
cross_val_score(rf, x, y, cv=10)
# Out:
# array([ -2.27780311,   0.56668245, -53.25664008,  -0.42309511,
#          0.58810773, -21.73525144,   0.41155707,  -1.21666822,
#          0.63157249,  -1.41407006])

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 69.39 %.

# %%
sns.pairplot(df[['New_business_density', 'Ease_of_doing_business']])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
